# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

people = pd.read_csv("people.csv")
people
# Out:
#       name  height  friends   gpa       sport       shoes
# 0   dakota      72      307  3.15  basketball    sneakers
# 1   hayden      68      335  3.50      tennis  flip-flops
# 2  charlie      61       34  1.10    baseball  flip-flops
# 3   kamryn      66      200  2.18      soccer    sneakers
# 4  emerson      65      213  3.06      soccer    sneakers
# 5   jessie      61      202  2.41  basketball  flip-flops
# 6   sawyer      67      314  2.96      tennis  flip-flops
# 7   london      64      436  3.98      soccer    sneakers

# %%
sns.scatterplot(data=people, x="gpa", y="friends", hue = "shoes").grid()

# %%
sns.lmplot(x="gpa", y="friends", hue = "shoes", data=people)
sns.set(rc = {'figure.figsize':(30,10)})

# %%
reviews = pd.read_csv("winereviews.csv")
reviews
#what country has the best wine
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
review2 = reviews.loc[(reviews.points == 100), ["country", "points"]].value_counts("country")

# %%
sns.barplot(x= review2.index, y= review2)
# Out:
# <AxesSubplot:xlabel='country'>
