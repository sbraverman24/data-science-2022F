# %% [markdown]
# # Python Practice
# ---
#
# ## Boptalk
#
# Boptalk is a secret language allowing those who know it to communicate in unreasonably long and silly sentences. For instance, if I wanted to say "hello" in Boptalk, I would say "hop e lop lop o".
#
# The logic is this: for each letter in the sentence you want to speak, if that letter is a vowel you simply say it, otherwise you add "op" to it.
#
# In the cell below, use the .input() function to get input from the user. (Look it up if you don't know how.)
#
# Then, taking that input, create and display the Boptalk output. For this problem, you can use strings alone.

# %%
h = input()
for x in h:
    if x == "a" or x == "e" or x == "i" or x == "o" or x == "u":
        print(x)
    else:
        print(x + "op")
# Out:
# Grilled cheese
# Gop
# rop
# i
# lop
# lop
# e
# dop
#  op
# cop
# hop
# e
# e
# sop
# e

# %% [markdown]
# ## One-line Boptalk 🌶️
#
# Now, can you use list comprehension to do it in one line (except the vowels declaration and input)?
#
# You will need to convert the list into a string with spaces inserted. Google how to do this.

# %%
f = input()
[g if g == "a" or g == "e" or g == "i" or g == "o" or g == "u" else g + "op" for g in f]
# Out:
# pollywog
# ['pop', 'o', 'lop', 'lop', 'yop', 'wop', 'o', 'gop']

# %% [markdown]
# ## Dictionaries 🌶️🌶️
#
# There is a Python file that you should have in the same directory as this Notebook, called book.py. It is a simple Python script that contains one very long list of lowercase words. You can use that list in this Notebook by importing it like so:
#
# ```python
# from book import words
# ```
#
# You will then have a list stored in the variable "words". Go ahead and import the data and output it to verify. (It is so long that you won't see all 58,110 words.)

# %%
from book import words
print(words)
# Out:
# ['despising', 'morbidity', 'assimilated', 'monostable', 'anodyne', 'alights', 'misdirecting', 'notify', 'licentious', 'lighthearted', 'triennial', 'polisher', 'blurring', 'merriest', 'girders', 'pagination', 'speedwell', 'range', 'entrusted', 'notation', 'volleyball', 'dwindle', 'sardines', 'corporatist', 'definitional', 'bovine', 'prohibitively', 'electro', 'smartest', 'frivolously', 'novelists', 'communicates', 'voyages', 'shatteringly', 'smallness', 'honeymooners', 'windings', 'enchantment', 'bedside', 'december', 'resistances', 'harp', 'kraal', 'wriggling', 'coauthor', 'editions', 'triteness', 'vamp', 'vamps', 'strained', 'stalactite', 'isomers', 'hilarious', 'acuter', 'gearbox', 'renew', 'coordinators', 'toys', 'swirling', 'dunked', 'inextinguishable', 'cry', 'considerate', 'girlfriends', 'sisters', 'race', 'vacuoles', 'amplified', 'stewardship', 'magnitude', 'visionaries', 'rescheduling', 'interpreter', 'neglect', 'reticulated', 'crowbar', 'handpicked', 'excitements', 'heavyweights', 'wonderingly', 'bibles', 'swayed', 'flexor', 'payloads', 'despondent', 'compositor', 'overindulgence', 'banks', 'indefinably', 'compatriots', 'bylaw', 'counterfeits', 'trombonist', 'encyclopaedic', 'conservator', 'unfailing', 'courteous', 'abstracted', 'invalidates', 'fumbling', 'orders', 'patented', 'drunkard', 'drownings', 'drawbridge', 'commonalities', 'aberration', 'galled', 'curmudgeons', 'bossier', 'pasturing', 'toying', 'voters', 'moralities', 'ticketed', 'recollected', 'prospective', 'appreciating', 'unfavourable', 'swads', 'soundproof', 'laudatory', 'lesser', 'protesting', 'advocated', 'stopover', 'gangland', 'fawned', 'vaguely', 'conducts', 'lima', 'automates', 'monetary', 'pitchdark', 'unoccupied', 'sufferer', 'plus', 'insults', 'garottes', 'earphones', 'beautician', 'echoing', 'palely', 'gnarled', 'boardings', 'singed', 'niftily', 'cowriter', 'guttersnipe', 'rice', 'thickset', 'pacemakers', 'floe', 'troy', 'demists', 'hones', 'beloved', 'argument', 'stalked', 'cheapish', 'contented', 'nipped', 'multiplies', 'shaves', 'silo', 'users', 'picked', 'amalgamations', 'civilly', 'prompts', 'gander', 'hinderer', 'normals', 'inertness', 'depositories', 'indispensability', 'constrains', 'watchdog', 'stewardesses', 'tabling', 'suture', 'endorsement', 'injected', 'undertakers', 'suction', 'sounded', 'boneless', 'poodle', 'tapered', 'tensor', 'codicils', 'throat', 'souvenir', 'militate', 'testing', 'avariciousness', 'cakes', 'curfews', 'purgatorial', 'facility', 'bum', 'quelled', 'resilience', 'repayment', 'stigmatised', 'unsafely', 'pederasts', 'bemoaning', 'teleprinter', 'babbles', 'promises', 'unsurfaced', 'fireball', 'eclairs', 'temptations', 'rethought', 'magic', 'lectureships', 'symbolically', 'science', 'interjected', 'yawl', 'devoid', 'extradition', 'plumed', 'burden', 'objects', 'affably', 'firstborn', 'improvements', 'reconsult', 'disability', 'consultations', 'cantaloupe', 'rechecking', 'adopts', 'unvanquished', 'piazzas', 'bats', 'bra', 'sprouted', 'weepy', 'bombast', 'longlost', 'complexity', 'stunner', 'topple', 'poison', 'mishearing', 'pampering', 'inauthenticity', 'paprika', 'aliening', 'snags', 'abetting', 'rad', 'outgrowths', 'beckon', 'meatier', 'symbolise', 'bleeper', 'hatful', 'miserly', 'paroxysm', 'immortally', 'chandeliers', 'bleached', 'theft', 'handiwork', 'keypad', 'suzerainty', 'reclothe', 'hellfire', 'gamesmen', 'bronchi', 'disintegrates', 'shortlived', 'substantiate', 'illmannered', 'fraternise', 'slips', 'chafes', 'requiring', 'brickbats', 'paramagnetic', 'mysterious', 'mill', 'torturer', 'miscarry', 'mutable', 'unseaworthiness', 'prospectuses', 'stack', 'masterwork', 'champion', 'quarrying', 'engulf', 'dishcloth', 'tulip', 'gullies', 'shred', 'diffracting', 'ameliorating', 'verbs', 'unpolluted', 'martins', 'themas', 'wheatgerm', 'stained', 'sparse', 'characterised', 'spewed', 'creditworthiness', 'bowel', 'ferrets', 'lightheartedly', 'foothill', 'tamest', 'quarrel', 'roasts', 'hygienist', 'pimpernel', 'forbids',  ...

# %% [markdown]
# Now the tricky part. Create a dictionary with 26 keys, each key being a letter of the alphabet. And, the value associated with each key is a list of all the words in the big word list that begin with that letter. Output it to verify.
#
# *Hint- you may not be able to do this efficiently in a single step.*

# %%
pollywog = {
    "a" : [a for a in words if a[0] == "a"],   
    "b" : [b for b in words if b[0] == "b"],
    "c" : [x for x in words if x[0] == "c"],
    "d" : [x for x in words if x[0] == "d"],
    "e" : [x for x in words if x[0] == "e"],
    "f" : [x for x in words if x[0] == "f"],
    "g" : [x for x in words if x[0] == "g"],
    "h" : [x for x in words if x[0] == "h"],
    "i" : [x for x in words if x[0] == "i"],
    "j" : [x for x in words if x[0] == "j"],
    "k" : [x for x in words if x[0] == "k"],
    "l" : [x for x in words if x[0] == "l"],
    "m" : [x for x in words if x[0] == "m"],
    "n" : [x for x in words if x[0] == "n"],
    "o" : [x for x in words if x[0] == "o"],
    "p" : [x for x in words if x[0] == "p"],
    "q" : [x for x in words if x[0] == "q"],
    "r" : [x for x in words if x[0] == "r"],
    "s" : [x for x in words if x[0] == "s"],
    "t" : [x for x in words if x[0] == "t"],
    "u" : [x for x in words if x[0] == "u"],
    "v" : [x for x in words if x[0] == "v"],
    "w" : [x for x in words if x[0] == "w"],
    "x" : [x for x in words if x[0] == "x"],
    "y" : [x for x in words if x[0] == "y"],
    "z" : [x for x in words if x[0] == "z"]
}
pollywog
# Out:
# {'a': ['assimilated',
#   'anodyne',
#   'alights',
#   'acuter',
#   'amplified',
#   'abstracted',
#   'aberration',
#   'appreciating',
#   'advocated',
#   'automates',
#   'argument',
#   'amalgamations',
#   'avariciousness',
#   'affably',
#   'adopts',
#   'aliening',
#   'abetting',
#   'ameliorating',
#   'accreted',
#   'arbitrageur',
#   'aurevoir',
#   'auditioning',
#   'appendage',
#   'arrowheads',
#   'airless',
#   'abject',
#   'arachnophobia',
#   'arrangement',
#   'ave',
#   'alleles',
#   'aerials',
#   'amaze',
#   'agreeably',
#   'apparelled',
#   'accuse',
#   'arced',
#   'arches',
#   'anyhow',
#   'applecart',
#   'aerodynamic',
#   'anything',
#   'arson',
#   'antibiotic',
#   'action',
#   'antistatic',
#   'alveolar',
#   'archive',
#   'averse',
#   'attainment',
#   'armpit',
#   'afforestation',
#   'abbreviating',
#   'abbreviates',
#   'antlion',
#   'autopsies',
#   'alive',
#   'accelerometer',
#   'altercate',
#   'adverse',
#   'amino',
#   'aorist',
#   'alphabet',
#   'admiration',
#   'assaulted',
#   'altarpieces',
#   'anagrammatic',
#   'auditing',
#   'anguish',
#   'adumbrated',
#   'adjusted',
#   'articulatory',
#   'avowing',
#   'antithetic',
#   'anomalies',
#   'aura',
#   'antidotes',
#   'angler',
#   'antibiotics',
#   'amazon',
#   'audited',
#   'ambivalence',
#   'avenues',
#   'appeasement',
#   'altering',
#   'anhydrous',
#   'anteaters',
#   'ambition',
#   'autocrats',
#   'adjudication',
#   'astute',
#   'abut',
#   'algal',
#   'apothecaries',
#   'ambling',
#   'avuncular',
#   'agitates',
#   'agriculture',
#   'annotations',
#   'angioplasty',
#   'air',
#   'accesses',
#   'amused',
#   'airiness',
#   'accompanies',
#   'audition',
#   'assignees',
#   'adjudges',
#   'assertiveness',
#   'annually',
#   'aardvark',
#   'astraddle',
#   'ascetic',
#   'airframes',
#   'agent',
#   'abloom',
#   'algebraist',
#   'accosting',
#   'anglers',
#   'amateurism',
#   'anaphoric',
#   'akimbo',
#   'actuality',
#   'abolition',
#   'alleges',
#   'addicted',
#   'avoirdupois',
#   'asian',
#   'aftercare',
#   'amber',
#   'associates',
#   'asphyxia',
#   'applauded',
#   'agoraphobic',
#   'anisotropy',
#   'acumen',
#   'applicability',
#   'aphelion',
#   'admittances',
#   'anthropologists',
#   'appraising',
#   'anteroom',
#   'analysed',
#   'amongst',
#   'animist',
#   'alliterate',
#   'acuity',
#   'anginal',
#   'aversion',
#   'alienate',
#   'allotments',
#   'affection',
#   'annotated',
#   'assegais',
#   'admirers',
#   'arguable',
#   'achy',
#   'attenders',
#   'atoll',
#   'assembles',
#   'awhile',
#   'absurdly',
#   'authorisations',
#   'avulsion',
#   'affirming',
#   'adventurous',
#   'autobiographies',
#   'affirmations',
#   'airily',
#   'affective',
#   'asynchronously',
#   'anniversary',
#   'anarchy',
#   'accumulators',
#   'accentuates',
#   'arena',
#   'agitating',
#   'artistically',
#   'asymptotic',
#   'apartness',
#   'applauding',
#   'arabians',
#   'acrobat',
#   'appease',
#   'acknowledge',
#   'arabia',
#   'armfuls',
#   'aristocratic',
#   'adulterous',
#   'admirable',
#   'aerobatics',
#   'abusively',
#   'arbitrageurs',
#   'acetal',
#   'announced',
#   'annihilate',
#   'arrears',
#   'autarchy',
#   'archived',
#   'antidote',
#   'academia',
#   'achingly',
#   'attentions',
#   'antenatal',
#   'alanine',
#   'architectural',
#   'allegiance',
#   'amphibia',
#   'affiliating',
#   'arteries',
#   'acidity',
#   'adamant',
#   'additively',
#   'appending',
#   'appendix',
#   'apprehend',
#   'airtight',
#   'anthropology',
#   'amounted',
#   'aiding',
#   'authenticity',
#   'alienation',
#   'accountancy',
#   'abstractly',
#   'amnesiac',
#   'ambiance',
#   'azores',
#   'analogues',
#   'avalanches',
#   'acorns',
#   'appropriates',
#   'antagonising',
#   'antedate',
#   'armada',
#   'apron',
#   'aids',
#   'assessors',
#   'amputation',
#   'abomination',
#   'abnormally',
#   'apes',
#   'ambivalent',
#   'appetites',
#   'accompanied',
#   'algorithmic',
#   'acids',
#   'appreciable',
#   'awkwardest',
#   'appealed',
#   'alluring',
#   'astray',
#   'alcoholics',
#   'archipelago',
#   'artists',
#   'appreciative',
#   'antiquities',
#   'alluvia',
#   'aboard',
#   'actuator',
#   'around',
#   'ape',
#   'advertise',
#   'authorising',
#   'analyses',
#   'acts',
#   'accessing',
#   'allotting',
#   'agonisingly',
#   'archetypal',
#   'absolutist',
#   'aggregation',
#   'animated',
#   'amputee',
#   'aspires',
#   'archaisms',
#   'amending',
#   'amusement',
#   'assented',
#   'attributes',
#   'aloof',
#   'amphibian',
#   'anemia',
#   'attachment',
#   'anticipate',
#   'appeaser',
#   'amulet',
#   'abnegation',
#   'accountants',
#   'artfully',
#   'assures',
#   'avoids',
#   'arachnids',
#   'appertain',
#   'abdicate',
#   'antigenic',
#   'awfully',
#   'almshouse',
#   'anoint',
#   'advantages',
#   'alumni',
#   'answer',
#   'anatomist',
#   'anywhere',
#   'attract',
#   'airships',
#   'aardwolf',
#   'aerosol',
#   'acclimatising',
#   'arthropod',
#   'axiomatically',
#   'abscissas',
#   'aspiration',
#   'aright',
#   'affording',
#   'assumptions',
#   'adventurer',
#   'alas',
#   'admirals',
#   'availing',
#   'addressed',
#   'ambience',
#   'authoritative',
#   'allayed',
#   'associatively',
#   'attics',
#   'arrogantly',
#   'adding',
#   'absentmindedness',
#   'ammeters',
#   'agreeing',
#   'awkwardly',
#   'accusals',
#   'april',
#   'astounds',
#   'attaching',
#   'administer',
#   'annunciation',
#   'amateurs',
#   'algerian',
#   'ally',
#   'axiom',
#   'aforementioned',
#   'accretion',
#   'anemic',
#   'arrays',
#   'aggravating',
#   'acuteness',
#   'acidly',
#   'alligators',
#   'adjudicate',
#   'adopt',
#   'ascertainable',
#   'aims',
#   'alumnus',
#   'ararat',
#   'addling',
#   'accordance',
#   'aint',
#   'artlessness',
#   'addled',
#   'assayer',
#   'aired',
#   'assessable',
#   'aha',
#   'aider',
#   'aircrews',
#   'agoraphobia',
#   'assistants',
#   'absences',
#   'athens',
#   'anchorages',
#   'ascribe',
#   'abroad',
#   'archaeologically',
#   'agonists',
#   'aesop',
#   'alembic',
#   'abdominal',
#   'apian',
#   'advertisers',
#   'antipathy',
#   'abash',
#   'adages',
#   'afloat',
#   'aupairs',
#   'anticlimax',
#   'astral',
#   'alarmism',
#   'adsorbed',
#   'allowable',
#   'admix',
#   'accelerating',
#   'abridge',
#   'allowances',
#   'agents',
#   'anatomy',
#   'addictions',
#   'antibodies',
#   'authorises',
#   'acquiescence',
#   'asymptotes',
#   'acquaints',
#   'ascertains',
#   'adapter',
#   'anorexic',
#   'annulment',
#   'attestation',
#   'accents',
#   'analytical',
#   'aprons',
#   'archivist',
#   'annuity',
#   'axis',
#   'announcers',
#   'aground',
#   'along',
#   'arrayed',
#   'affected',
#   'accordionist',
#   'absorbent',
#   'alkyl',
#   'amiss',
#   'abyss',
#   'auxiliaries',
#   'adjustable',
#   'attach',
#   'adenoma',
#   'accusers',
#   'assigning',
#   'abandonment',
#   'afforested',
#   'afflux',
#   'approves',
#   'apprising',
#   'assyrian',
#   'alt',
#   'analogies',
#   'airlock',
#   'adder',
#   'ablative',
#   'adoptive',
#   'axehead',
#   'abjured',
#   'arthropods',
#   'alight',
#   'acquittal',
#   'accelerates',
#   'anthem',
#   'anamorphic',
#   'adversary',
#   'advantaged',
#   'abilities',
#   'aversions',
#   'anacondas',
#   'apse',
#   'alertly',
#   'antenna',
#   'accompany',
#   'acting',
#   'abstemiously',
#   'aster',
#   'aloe',
#   'allocators',
#   'aromaticity',
#   'affront',
#   'adonis',
#   'analogous',
#   'automatically',
#   'abounded',
#   'admission',
#   'ambulant',
#   'attila',
#   'advise',
#   'anthropic',
#   'asserted',
#   'aspirin',
#   'audio',
#   'auburn',
#   'arguing',
#   'amphetamine',
#   'artlessly',
#   'aforethought',
#   'apprehensive',
#   'adherent',
#   'adults',
#   'attended',
#   'axiomatising',
#   'alining',
#   'auteur',
#   'augmentation',
#   'artichokes',
#   'available',
#   'athleticism',
#   'analogise',
#   'accented',
#   'accusatory',
#   'appetite',
#   'attractors',
#   'alacrity',
#   'accenting',
#   'apprentices',
#   'adjourns',
#   'arrhythmia',
#   'autocratically',
#   'advertises',
#   'abbreviations',
#   'allegory',
#   'annoyance',
#   'aby',
#   'actinides',
#   'alright',
#   'aggrievedly',
#   'across',
#   'armful',
#   'adorable',
#   'absenting',
#   'adage',
#   'arrests',
#   'abstracting',
#   'automobile',
#   'averted',
#   'addressing',
#   'alphanumeric',
#   'assiduous',
#   'annual',
#   'agio',
#   'assignable',
#   'acquittals',
#   'adherer',
#   'accompanying',
#   'automatic',
#   'abortive',
#   'aliened',
#   'abandon',
#   'advises',
#   'actions',
#   'apprenticeship',
#   'anoints',
#   'apposite',
#   'anti',
#   'aviary',
#   'albumin',
#   'astounding',
#   'admin',
#   'allows',
#   'abacus',
#   'acid',
#   'allergic',
#   'alts',
#   'adjacent',
#   'ampersand',
#   'astonish',
#   'adduced',
#   'algorithms',
#   'accrediting',
#   'acre',
#   'addles',
#   'annexation',
#   'authoritarian',
#   'arrives',
#   'aggregations',
#   'astronauts',
#   'autobiographical',
#   'aphasia',
#   'antimatter',
#   'applicant',
#   'agendas',
#   'angora',
#   'antiseptics',
#   'ascended',
#   'aromatherapist',
#   'acerbic',
#   'alertness',
#   'atones',
#   'agronomist',
#   'allegri',
#   'aerodromes',
#   'alluded',
#   'acrid',
#   'assemblage',
#   'aortas',
#   'appealingly',
#   'aft',
#   'anionic',
#   'abortion',
#   'adapting',
#   'appointees',
#   'authoring',
#   'aquanaut',
#   'alkaloids',
#   'assisted',
#   'associateship',
#   'applicators',
#   'alliteration',
#   'acentric',
#   'arbitrary',
#   'append',
#   'allotted',
#   'adulterers',
#   'antidepressant',
#   'atherosclerosis',
#   'anterior',
#   'amen',
#   'antennas',
#   'advantageous',
#   'albumen',
#   'annoyer',
#   'arthritic',
#   'actually',
#   'abstractions',
#   'aroused',
#   'allegation',
#   'augury',
#   'admonitions',
#   'ampersands',
#   'abutting',
#   'appeal',
#   'attributive',
#   'abraham',
#   'autocrat',
#   'anachronistic',
#   'amazes',
#   'anthropometric',
#   'aztec',
#   'amnesties',
#   'angle',
#   'aspect',
#   'adhering',
#   'actualisation',
#   'advocacy',
#   'advising',
#   'ankle',
#   'agreed',
#   'absent',
#   'antique',
#   'authoress',
#   'anemones',
#   'affixing',
#   'aerify',
#   'abducting',
#   'agility',
#   'anodised',
#   'arbour',
#   'aeroplane',
#   'adjudicators',
#   'adulterations',
#   'amalgamates',
#   'alaska',
#   'assimilate',
#   'axle',
#   'ambiguities',
#   'ampere',
#   'aegis',
#   'aerobe',
#   'adversity',
#   'atrophying',
#   'arbitrated',
#   'antelope',
#   'archway',
#   'aneurysms',
#   'aridity',
#   'accentuated',
#   'astrologers',
#   'attendees',
#   'attributions',
#   'acceding',
#   'atomic',
#   'azalea',
#   'arts',
#   'accosted',
#   'alerts',
#   'adulterating',
#   'aircraft',
#   'absorbing',
#   'arises',
#   'averages',
#   'artichoke',
#   'airgun',
#   'abhorred',
#   'auras',
#   'antipathies',
#   'arranged',
#   'albeit',
#   'astrophysics',
#   'anchors',
#   'antagonised',
#   'antediluvian',
#   'aspirated',
#   'arent',
#   'affidavits',
#   'arms',
#   'associating',
#   'answered',
#   'anticipations',
#   'activators',
#   'attracting',
#   'agings',
#   'alighting',
#   'areas',
#   'affidavit',
#   'ancestries',
#   'ambulance',
#   'accumulation',
#   'await',
#   'awaits',
#   'afflicting',
#   'appraisal',
#   'anaesthetising',
#   'adaptive',
#   'accrual',
#   'affiliates',
#   'aidesdecamp',
#   'annular',
#   'adulterer',
#   'ahem',
#   'azure',
#   'advancements',
#   'absurder',
#   'army',
#   'accounting',
#   'anally',
#   'assurance',
#   'analysers',
#   'asks',
#   'array',
#   'anaphora',
#   'antidepressants',
#   'assume',
#   'attractions',
#   'avails',
#   'aussies',
#   'articulacy',
#   'alternatives',
#   'arm',
#   'accompaniments',
#   'alternator',
#   'ancillary',
#   'alignment',
#   'admiral',
#   'accursed',
#   'appellations',
#   'admonition',
#   'airline',
#   'astonishment',
#   'affirmatively',
#   'antithetical',
#   'ammo',
#   'aerodynamically',
#   'african',
#   'aerially',
#   'adaptively',
#   'administratively',
#   'admiring',
#   'against',
#   'archetypical',
#   'accolade',
#   'admonished',
#   'astrophysicists',
#   'adrenaline',
#   'arbiter',
#   'accra',
#   'anvils',
#   'anonymity',
#   'arabic',
#   'argent',
#   'attachable',
#   'ascertained',
#   'agriculturalists',
#   'awn',
#   'arrange',
#   'abeyance',
#   'abundances',
#   'aubergines',
#   'abutment',
#   'apologises',
#   'applicator',
#   'artefacts',
#   'appointments',
#   'alb',
#   'aquariums',
#   'avantgarde',
#   'applepie',
#   'alkaline',
#   'agnostics',
#   'awaken',
#   'amputees',
#   'anomic',
#   'arduous',
#   'appreciably',
#   'aspirational',
#   'anxiously',
#   'anchored',
#   'apathetically',
#   'associated',
#   'altarpiece',
#   'abbe',
#   'assistant',
#   'artful',
#   'asterisks',
#   'appraisingly',
#   'assignments',
#   'apathy',
#   'apoplexy',
#   'assertive',
#   'altar',
#   'acquaint',
#   'appearance',
#   'and',
#   'assignment',
#   'antic',
#   'abbot',
#   'accession',
#   'arithmetic',
#   'adoption',
#   'acquainted',
#   'an',
#   'anaemia',
#   'accrued',
#   'abstinent',
#   'actuation',
#   'absurdist',
#   'adepts',
#   'avidity',
#   'archivists',
#   'abattoir',
#   'adherers',
#   'aberdeen',
#   'accumulative',
#   'alligator',
#   'amine',
#   'afflictions',
#   'aspic',
#   'advantage',
#   'acupuncture',
#   'arousing',
#   'ascending',
#   'apprehension',
#   'achievement',
#   'apparel',
#   'admissibility',
#   'amid',
#   'accidents',
#   'atlases',
#   'algebra',
#   'apprehensively',
#   'abounds',
#   'acclamations',
#   'adhesions',
#   'armourers',
#   'actionable',
#   'adit',
#   'addendum',
#   'astronomer',
#   'astigmatic',
#   'anxieties',
#   'ablebodied',
#   'ageing',
#   'assyria',
#   'afterglow',
#   'adjoin',
#   'archetypes',
#   'antler',
#   'attenuator',
#   'amenorrhoea',
#   'accomplishment',
#   'aerodrome',
#   'adjournment',
#   'avionics',
#   'anon',
#   'armourer',
#   'anechoic',
#   'abraded',
#   'assessed',
#   'ascendency',
#   'assigns',
#   'anaerobically',
#   'adders',
#   'airbus',
#   'answering',
#   'angrier',
#   'alpaca',
#   'alley',
#   'auditor',
#   'abominate',
#   'abstain',
#   'adulthood',
#   'attiring',
#   'acclimatisation',
#   'argon',
#   'amuck',
#   'agglomerated',
#   'affecting',
#   'amoebae',
#   'asylums',
#   'aliquots',
#   'antecedent',
#   'angina',
#   'allot',
#   'adversities',
#   'anklet',
#   'antonyms',
#   'analysis',
#   'abomb',
#   'armbands',
#   'anachronisms',
#   'anonym',
#   'antiquarian',
#   'additions',
#   'annealer',
#   'autumns',
#   'attached',
#   'auditive',
#   'austere',
#   'amanuensis',
#   'antipodes',
#   'accomplices',
#   'auditors',
#   'apples',
#   'anarchist',
#   'aurora',
#   'amortisation',
#   'austerely',
#   'ammunition',
#   'acquires',
#   'aspirating',
#   'adumbrating',
#   'absoluteness',
#   'appals',
#   'aloneness',
#   'attuned',
#   'aegean',
#   'advancement',
#   'albatross',
#   'avian',
#   'alchemical',
#   'ardency',
#   'antitheses',
#   'avenged',
#   'authenticates',
#   'absolutists',
#   'abetted',
#   'approbation',
#   'analogical',
#   'annuities',
#   'alchemist',
#   'arrangeable',
#   'assembled',
#   'artless',
#   'aerating',
#   'absolves',
#   'adjourned',
#   'achromatic',
#   'attending',
#   'articulated',
#   'achings',
#   'archer',
#   'asterisk',
#   'amelioration',
#   'allude',
#   'apprehensions',
#   'adjoins',
#   'absconded',
#   'artificiality',
#   'authoritarianism',
#   'acapulco',
#   'abscond',
#   'alacarte',
#   'aristocracies',
#   'agouti',
#   'assiduously',
#   'assailing',
#   'absurdities',
#   'applying',
#   'answers',
#   'antecedents',
#   'arouse',
#   'advisability',
#   'awakenings',
#   'alternators',
#   'anthropomorphising',
#   'auctioning',
#   'at',
#   'aerobraking',
#   'allotropic',
#   'amplification',
#   'armoured',
#   'airraid',
#   'arbitrator',
#   'ambitiously',
#   'awkward',
#   'alibis',
#   'airconditioned',
#   'amman',
#   'archers',
#   'angularity',
#   'avens',
#   'authenticated',
#   'accusal',
#   'another',
#   'augmentations',
#   'asbestos',
#   ...],
#  'b': ['blurring',
#   'bovine',
#   'bedside',
#   'bibles',
#   'banks',
#   'bylaw',
#   'bossier',
#   'beautician',
#   'boardings',
#   'beloved',
#   'boneless',
#   'bum',
#   'bemoaning',
#   'babbles',
#   'burden',
#   'bats',
#   'bra',
#   'bombast',
#   'beckon',
#   'bleeper',
#   'bleached',
#   'bronchi',
#   'brickbats',
#   'bowel',
#   'buckling',
#   'barked',
#   'buttonholed',
#   'bali',
#   'buckshot',
#   'biotechnologist',
#   'busies',
#   'buffing',
#   'beaus',
#   'breathed',
#   'ball',
#   'brainstorms',
#   'birdtables',
#   'bunk',
#   'baltic',
#   'borer',
#   'badtempered',
#   'beseeches',
#   'buffoons',
#   'barge',
#   'bleakly',
#   'bludgeoning',
#   'blunting',
#   'boring',
#   'bawled',
#   'balmy',
#   'braincell',
#   'broadcasts',
#   'beefs',
#   'briny',
#   'begone',
#   'buddings',
#   'boomeranging',
#   'bathhouse',
#   'ballyhoo',
#   'bloodcurdling',
#   'boxed',
#   'bridals',
#   'belladonna',
#   'bogs',
#   'boilermakers',
#   'ballades',
#   'bellies',
#   'brooch',
#   'bulbous',
#   'baloney',
#   'blockbusting',
#   'bender',
#   'boston',
#   'batmen',
#   'bruiser',
#   'bulges',
#   'brahman',
#   'brutalism',
#   'bluebottles',
#   'brotherinlaw',
#   'brogues',
#   'bigger',
#   'bled',
#   'batiks',
#   'bail',
#   'balloon',
#   'bodes',
#   'biota',
#   'bored',
#   'bridesmaid',
#   'bulkiest',
#   'bilharzia',
#   'baulking',
#   'boarder',
#   'bin',
#   'busied',
#   'bespoke',
#   'bedouin',
#   'bustle',
#   'breach',
#   'boggled',
#   'breakthrough',
#   'briers',
#   'bauxite',
#   'bathing',
#   'bettering',
#   'breakdowns',
#   'binds',
#   'bottler',
#   'brutes',
#   'billion',
#   'boomed',
#   'bloomy',
#   'bureaucrats',
#   'barbarously',
#   'bindery',
#   'beneficial',
#   'bugger',
#   'braces',
#   'briar',
#   'batching',
#   'branch',
#   'bloat',
#   'boney',
#   'bureaucracy',
#   'bloodstone',
#   'bean',
#   'busts',
#   'brusquely',
#   'bishop',
#   'breaded',
#   'briefcase',
#   'bakings',
#   'boggy',
#   'biddings',
#   'bounced',
#   'braw',
#   'biofeedback',
#   'breaking',
#   'bilges',
#   'bitterness',
#   'brooded',
#   'bestial',
#   'bodywork',
#   'bloodstain',
#   'breathes',
#   'bang',
#   'bondholders',
#   'bisects',
#   'bedevilled',
#   'birthmark',
#   'bittersweet',
#   'baseness',
#   'bargain',
#   'bilingualism',
#   'bosons',
#   'barring',
#   'blackmailer',
#   'boastfulness',
#   'botanical',
#   'blue',
#   'beholding',
#   'balder',
#   'belongs',
#   'barbecued',
#   'butchers',
#   'bluff',
#   'braiding',
#   'bought',
#   'buckminsterfullerene',
#   'buff',
#   'blending',
#   'browser',
#   'backing',
#   'beheading',
#   'bide',
#   'betoken',
#   'bookish',
#   'balm',
#   'birth',
#   'bouncer',
#   'buggies',
#   'believably',
#   'between',
#   'bronchitis',
#   'batsman',
#   'bandaging',
#   'bawdy',
#   'blast',
#   'backwash',
#   'barbecues',
#   'booing',
#   'bear',
#   'blindfolds',
#   'bigamous',
#   'bill',
#   'beeline',
#   'bookkeeper',
#   'barking',
#   'biographically',
#   'beaters',
#   'brainpower',
#   'bypassing',
#   'baptismal',
#   'blackboard',
#   'beseeched',
#   'black',
#   'brutishness',
#   'barnacles',
#   'biodegradable',
#   'bananas',
#   'baptise',
#   'breastplate',
#   'brandishes',
#   'begot',
#   'blackboards',
#   'beneficially',
#   'boxing',
#   'book',
#   'bloomed',
#   'biographers',
#   'begrudgingly',
#   'bifocals',
#   'beguilement',
#   'backstage',
#   'bloodlust',
#   'bursaries',
#   'buyer',
#   'bearer',
#   'broadsheet',
#   'brightest',
#   'basis',
#   'barer',
#   'brawl',
#   'bile',
#   'blueish',
#   'bowsprit',
#   'borrowable',
#   'barricade',
#   'belly',
#   'binge',
#   'briefcases',
#   'blunderbuss',
#   'beadyeyed',
#   'beatifies',
#   'bobtails',
#   'byes',
#   'bigapple',
#   'bop',
#   'broadens',
#   'belting',
#   'beverages',
#   'befall',
#   'belled',
#   'baptism',
#   'boughs',
#   'brigade',
#   'bootlaces',
#   'bendable',
#   'belief',
#   'bromide',
#   'bullfight',
#   'bigots',
#   'bathtubs',
#   'bahamas',
#   'blip',
#   'barbers',
#   'boxwood',
#   'blow',
#   'blowers',
#   'based',
#   'buries',
#   'bellows',
#   'baleen',
#   'burner',
#   'beneficent',
#   'berthed',
#   'baptised',
#   'bifurcations',
#   'blares',
#   'barnstorming',
#   'biker',
#   'burgers',
#   'bricklayers',
#   'bayonets',
#   'brightly',
#   'briefly',
#   'bewitched',
#   'betrothed',
#   'bipedal',
#   'burgeons',
#   'belgium',
#   'bugbear',
#   'bauble',
#   'biceps',
#   'bonneted',
#   'boozed',
#   'baths',
#   'bridal',
#   'blaming',
#   'bookbinding',
#   'bonbons',
#   'breakers',
#   'beeches',
#   'beanstalks',
#   'blimp',
#   'baselines',
#   'boorishness',
#   'boomerangs',
#   'bantam',
#   'bevel',
#   'beetles',
#   'bereavements',
#   'blizzards',
#   'borrowers',
#   'blocked',
#   'bumps',
#   'borrowing',
#   'biotic',
#   'bellyful',
#   'broadest',
#   'blustery',
#   'bouncy',
#   'bassoon',
#   'burgeoning',
#   'bedrooms',
#   'bottlenecks',
#   'bastardised',
#   'beaches',
#   'buffoonery',
#   'breathalysed',
#   'begs',
#   'backspace',
#   'baggiest',
#   'bookstall',
#   'butlers',
#   'bursars',
#   'ballad',
#   'belle',
#   'basque',
#   'being',
#   'bootstraps',
#   'benzene',
#   'beholds',
#   'browning',
#   'brasher',
#   'beauteous',
#   'begins',
#   'barn',
#   'beef',
#   'brotherly',
#   'buoy',
#   'betrays',
#   'branchy',
#   'blur',
#   'beatitudes',
#   'barbaric',
#   'bilge',
#   'belligerently',
#   'bargainers',
#   'booby',
#   'bustard',
#   'bearers',
#   'brightened',
#   'bap',
#   'bornagain',
#   'bacteriophage',
#   'beaming',
#   'ballot',
#   'bestowed',
#   'belike',
#   'blotch',
#   'blades',
#   'brainteasers',
#   'brace',
#   'blowtorches',
#   'butane',
#   'belabour',
#   'bather',
#   'bypath',
#   'budgets',
#   'brunch',
#   'boggles',
#   'bodices',
#   'blackhead',
#   'bassist',
#   'bloodied',
#   'babbled',
#   'beadier',
#   'bossed',
#   'bosses',
#   'brainlessness',
#   'barefaced',
#   'banded',
#   'burdening',
#   'bemuse',
#   'braid',
#   'bundled',
#   'bricabrac',
#   'breathable',
#   'batteries',
#   'before',
#   'browsed',
#   'bewailed',
#   'beleaguered',
#   'blackberry',
#   'balloted',
#   'bared',
#   'binding',
#   'bugbears',
#   'brisbane',
#   'beet',
#   'beauty',
#   'buckle',
#   'batted',
#   'bitters',
#   'barks',
#   'badminton',
#   'bubblegum',
#   'boringly',
#   'baal',
#   'blackmailed',
#   'bleach',
#   'bye',
#   'buttercup',
#   'building',
#   'birdcage',
#   'birds',
#   'bedpost',
#   'bloodless',
#   'bankruptcies',
#   'booming',
#   'bruising',
#   'backless',
#   'barrier',
#   'bricks',
#   'brutal',
#   'bobble',
#   'bracelet',
#   'brokenhearted',
#   'bosun',
#   'backchat',
#   'bathroom',
#   'balusters',
#   'busiest',
#   'boast',
#   'browbeaten',
#   'blotting',
#   'beckoned',
#   'befits',
#   'boors',
#   'bloodsport',
#   'beneath',
#   'burdock',
#   'bakery',
#   'blown',
#   'blowed',
#   'bolstering',
#   'benefactors',
#   'behaved',
#   'birthmarks',
#   'blueberry',
#   'bumped',
#   'breweries',
#   'batten',
#   'boundedness',
#   'benightedly',
#   'bisected',
#   'burped',
#   'benefited',
#   'blenders',
#   'brim',
#   'blatant',
#   'breeches',
#   'bluebell',
#   'begged',
#   'bouncers',
#   'brags',
#   'bestiary',
#   'baaing',
#   'bedtime',
#   'bedevils',
#   'belatedly',
#   'busying',
#   'baklavas',
#   'bushland',
#   'boa',
#   'bung',
#   'boson',
#   'brocade',
#   'beck',
#   'boos',
#   'bypaths',
#   'bombards',
#   'befalling',
#   'bafflement',
#   'boastfully',
#   'bailed',
#   'binomial',
#   'barbie',
#   'bandage',
#   'boyish',
#   'bungles',
#   'buffalo',
#   'brilliantly',
#   'burglars',
#   'budded',
#   'bias',
#   'battlement',
#   'barracuda',
#   'barges',
#   'behinds',
#   'badged',
#   'bothered',
#   'bricked',
#   'bonuses',
#   'behead',
#   'bowstring',
#   'belgrade',
#   'breeders',
#   'battles',
#   'binders',
#   'budging',
#   'butterflies',
#   'boreholes',
#   'banister',
#   'butting',
#   'beneficiary',
#   'brighten',
#   'breaker',
#   'blessing',
#   'bradycardia',
#   'beardless',
#   'barnyard',
#   'bravery',
#   'blandishments',
#   'bisexuals',
#   'backfires',
#   'blackout',
#   'bittern',
#   'blundering',
#   'binnacle',
#   'biennial',
#   'blade',
#   'birthrate',
#   'birdcages',
#   'byelection',
#   'blasphemously',
#   'barracking',
#   'barricaded',
#   'burrowed',
#   'bolero',
#   'bleeders',
#   'blackmailing',
#   'breakwater',
#   'bloodbath',
#   'bisect',
#   'burners',
#   'boer',
#   'braze',
#   'binder',
#   'biplanes',
#   'brandished',
#   'banshees',
#   'booklet',
#   'beneficiaries',
#   'blurted',
#   'biting',
#   'backgrounds',
#   'bagful',
#   'billed',
#   'bustles',
#   'branding',
#   'breakage',
#   'booms',
#   'bonds',
#   'blurbs',
#   'baa',
#   'bayed',
#   'bitches',
#   'brittleness',
#   'blurting',
#   'bragging',
#   'bragged',
#   'brokerage',
#   'boldface',
#   'beam',
#   'bedclothes',
#   'bannister',
#   'bronze',
#   'biology',
#   'benefactress',
#   'brainwashed',
#   'busier',
#   'beat',
#   'broth',
#   'backpack',
#   'beholden',
#   'berths',
#   'blacklisting',
#   'bonnet',
#   'broadsword',
#   'ballade',
#   'biographical',
#   'bluffing',
#   'beret',
#   'blamelessness',
#   'bewitch',
#   'burnishing',
#   'bloodsports',
#   'became',
#   'bedevilment',
#   'browbeat',
#   'breakin',
#   'battlegrounds',
#   'begets',
#   'braggarts',
#   'bookbinders',
#   'beetle',
#   'backstroke',
#   'bodybuilding',
#   'bristles',
#   'barony',
#   'breadandbutter',
#   'bombasts',
#   'broadcaster',
#   'burps',
#   'blossomed',
#   'byelaws',
#   'bed',
#   'blanked',
#   'brewery',
#   'bushing',
#   'battering',
#   'bytes',
#   'bares',
#   'binodal',
#   'blowdried',
#   'breaths',
#   'butler',
#   'babble',
#   'block',
#   'bode',
#   'buzzing',
#   'big',
#   'bisexuality',
#   'bunked',
#   'banked',
#   'benignity',
#   'behind',
#   'bacteriological',
#   'buccaneer',
#   'bestknown',
#   'beatified',
#   'booklets',
#   'brutalise',
#   'brutish',
#   'bedchamber',
#   'brays',
#   'bumpkins',
#   'breastfeeding',
#   'bushel',
#   'biologist',
#   'barbarity',
#   'barracks',
#   'beguiled',
#   'buttermilk',
#   'belied',
#   'beak',
#   'brokered',
#   'boor',
#   'browses',
#   'blockbusters',
#   'buzzards',
#   'beachcomber',
#   'blacksmiths',
#   'broadband',
#   'brows',
#   'blusters',
#   'bugler',
#   'befalls',
#   'betrayals',
#   'braided',
#   'browbeating',
#   'bamboozles',
#   'booed',
#   'belong',
#   'blench',
#   'braised',
#   'butchery',
#   'brims',
#   'bereaving',
#   'breadwinner',
#   'builder',
#   'believe',
#   'bribing',
#   'benelux',
#   'bedbugs',
#   'bamboozle',
#   'blabs',
#   'brussels',
#   'buggering',
#   'burgundy',
#   'batch',
#   'brothels',
#   'balanced',
#   'bismarck',
#   'bettered',
#   'belittle',
#   'brooches',
#   'butcher',
#   'belonged',
#   'baited',
#   'beached',
#   'brunts',
#   'borstals',
#   'brail',
#   'bulks',
#   'bestowing',
#   'brimmed',
#   'boon',
#   'broadening',
#   'blare',
#   'billow',
#   'bonanza',
#   'break',
#   'behaving',
#   'bossiest',
#   'bandwagon',
#   'burdened',
#   'bass',
#   'brushwork',
#   'beholder',
#   'bearskin',
#   'brooms',
#   'birefringence',
#   'bugs',
#   'bossiness',
#   'banana',
#   'bejewel',
#   'beachside',
#   'blowpipes',
#   'blotches',
#   'bobs',
#   'braille',
#   'bell',
#   'betel',
#   'baffle',
#   'bleating',
#   'breezy',
#   'bonbon',
#   'branched',
#   'banged',
#   'bookshop',
#   'belches',
#   'bushels',
#   'bloodstains',
#   'bailout',
#   'basreliefs',
#   'bleakness',
#   'bestirring',
#   'benignly',
#   'bobsled',
#   'blackshirts',
#   'battle',
#   'bilinguals',
#   'blazers',
#   'berets',
#   'burping',
#   'bouquet',
#   'bedpans',
#   'brutality',
#   'bulldozers',
#   'bloodlessness',
#   'bagpipe',
#   'bake',
#   'bandstand',
#   'biotechnological',
#   'brabble',
#   'blinded',
#   'baggier',
#   'bandits',
#   'bevels',
#   'bookie',
#   'bogglingly',
#   'boot',
#   'baronet',
#   'breadcrumbs',
#   'busting',
#   'bookmaking',
#   'beep',
#   'binary',
#   'blitzkrieg',
#   'births',
#   'baffled',
#   'badger',
#   'buffer',
#   'basketful',
#   'braced',
#   'began',
#   'bagpiper',
#   'blindingly',
#   'billable',
#   'boxtops',
#   'backdrop',
#   'biscuits',
#   'barbarian',
#   'bluntness',
#   'buttocks',
#   'bookbinder',
#   'bottom',
#   'biomass',
#   'bestselling',
#   'bombshell',
#   'bleaker',
#   'bankrupt',
#   'boilers',
#   'broking',
#   'behindhand',
#   'bowie',
#   'buffet',
#   'bookies',
#   'biochemical',
#   'bacterium',
#   'bootstrap',
#   'blasphemer',
#   'backgammon',
#   'bowdlerising',
#   'buttercups',
#   'balaclava',
#   'broadmindedness',
#   'bounce',
#   'begging',
#   'beelines',
#   'bumpers',
#   'bloodstream',
#   'biopsy',
#   'boating',
#   'brainlessly',
#   'backlit',
#   'bartered',
#   'bewailing',
#   'bards',
#   'bicentennial',
#   'biplane',
#   'brook',
#   'brimming',
#   'baseballs',
#   'bruisers',
#   'brutus',
#   'biscuity',
#   'bilingual',
#   'barter',
#   'blesses',
#   'betting',
#   'bobbies',
#   'beefiest',
#   'basted',
#   'backdate',
#   'birthright',
#   'brewing',
#   'bills',
#   'budget',
#   'beguile',
#   'bannisters',
#   'bitter',
#   'boxful',
#   'bypasses',
#   'booze',
#   'browned',
#   'benefit',
#   'boils',
#   'bloodsuckers',
#   'busters',
#   'broodingly',
#   'barriers',
#   'bulged',
#   'beryllium',
#   'beeps',
#   'buttered',
#   'brasses',
#   'blasphemers',
#   'brickred',
#   'bullfrog',
#   'blowup',
#   'busy',
#   'bluebells',
#   'bystanders',
#   'bathtub',
#   'biz',
#   'brushoff',
#   'brittle',
#   'blatantly',
#   'belittling',
#   'bissau',
#   'baubles',
#   'beadle',
#   'bestsellers',
#   'basing',
#   'betroths',
#   'bowels',
#   'biblicists',
#   'boaster',
#   'bloody',
#   'boom',
#   'bushiest',
#   'bearably',
#   'batter',
#   'bothers',
#   'begrudge',
#   'bluebird',
#   'braved',
#   'bifurcated',
#   'buffers',
#   'basses',
#   'borates',
#   'bowlder',
#   'blondest',
#   'barons',
#   'briefest',
#   'banqueting',
#   'bailiwick',
#   'borate',
#   'bedazzle',
#   'balmoral',
#   'blithe',
#   'burgeon',
#   'bionic',
#   'bristling',
#   'barrenness',
#   'boorish',
#   'braise',
#   'barker',
#   'briefing',
#   'bonding',
#   'burr',
#   'bully',
#   'brasilia',
#   'brushing',
#   'brazenly',
#   'buoyantly',
#   'both',
#   'boozes',
#   'bodiless',
#   'bucketfuls',
#   'bureaucratisation',
#   'beaded',
#   'booksellers',
#   'blabber',
#   'baguette',
#   'buccaneering',
#   'beings',
#   'backpedalling',
#   'bewildering',
#   'blinking',
#   'beams',
#   'bigness',
#   'bobbins',
#   'broadness',
#   'burbles',
#   'bacteriology',
#   'breadboard',
#   'booboo',
#   'blabbed',
#   'berry',
#   'bandwidths',
#   'brotherhood',
#   'blockade',
#   'borstal',
#   'bestir',
#   'borrower',
#   'brown',
#   'boorishly',
#   'bridling',
#   'babysitter',
#   'beg',
#   'boo',
#   'barefoot',
#   'brighter',
#   'back',
#   'baseless',
#   'blurts',
#   'brabbled',
#   'billionaire',
#   'borax',
#   'backfired',
#   'bones',
#   'behemoth',
#   'blotchy',
#   'be',
#   'budding',
#   'blemishes',
#   'babysitting',
#   'bewail',
#   'blackjack',
#   'bookmakers',
#   'blobs',
#   'biped',
#   'britons',
#   'board',
#   ...],
#  'c': ['corporatist',
#   'communicates',
#   'coauthor',
#   'coordinators',
#   'cry',
#   'considerate',
#   'crowbar',
#   'compositor',
#   'compatriots',
#   'counterfeits',
#   'conservator',
#   'courteous',
#   'commonalities',
#   'curmudgeons',
#   'conducts',
#   'cowriter',
#   'cheapish',
#   'contented',
#   'civilly',
#   'constrains',
#   'codicils',
#   'cakes',
#   'curfews',
#   'consultations',
#   'cantaloupe',
#   'complexity',
#   'chandeliers',
#   'chafes',
#   'champion',
#   'characterised',
#   'creditworthiness',
#   'counteracting',
#   'concepts',
#   'churchyard',
#   'curbed',
#   'couturier',
#   'causation',
#   'contraction',
#   'comptroller',
#   'casanova',
#   'conflation',
#   'clause',
#   'cropper',
#   'contingency',
#   'cannibalistic',
#   'connotes',
#   'coursebook',
#   'clans',
#   'chirps',
#   'congestion',
#   'culminated',
#   'cookware',
#   'columnists',
#   'crawls',
#   'composure',
#   'celebrations',
#   'cordite',
#   'cooped',
#   'caters',
#   'crashers',
#   'cationic',
#   'conspecific',
#   'communique',
#   'chatterer',
#   'coincided',
#   'counterbalance',
#   'chequebooks',
#   'condenser',
#   'cuddle',
#   'clothe',
#   'complexion',
#   'certifying',
#   'capillaries',
#   'czars',
#   'crescendo',
#   'centroids',
#   'conform',
#   'cadged',
#   'convertibility',
#   'contaminant',
#   'conjuring',
#   'crusted',
#   'crookedness',
#   'chanteuse',
#   'courthouse',
#   'clinches',
#   'conception',
#   'catchphrase',
#   'colliding',
#   'considerations',
#   'chekov',
#   'chieftains',
#   'cheating',
#   'clip',
#   'creamery',
#   'chipmunk',
#   'cannon',
#   'centurion',
#   'childbirth',
#   'connecting',
#   'circumscribe',
#   'circularly',
#   'confections',
#   'commonwealth',
#   'cosmology',
#   'chorales',
#   'championing',
#   'cupped',
#   'commodes',
#   'compressors',
#   'comfort',
#   'counties',
#   'clubhouse',
#   'captures',
#   'culminates',
#   'condescended',
#   'career',
#   'cygnets',
#   'coital',
#   'coronal',
#   'crudeness',
#   'commerce',
#   'caterpillar',
#   'cockerels',
#   'cams',
#   'colloquia',
#   'chin',
#   'chides',
#   'coiling',
#   'congo',
#   'creeks',
#   'coffees',
#   'cereal',
#   'casino',
#   'cowed',
#   'chloroforming',
#   'currants',
#   'caravan',
#   'communes',
#   'crudity',
#   'charlatan',
#   'constant',
#   'chronicles',
#   'choreographic',
#   'cohabitees',
#   'cities',
#   'coble',
#   'constitutionality',
#   'cut',
#   'contemporaneity',
#   'carded',
#   'crag',
#   'conveyancing',
#   'checklist',
#   'corpulent',
#   'cataclysm',
#   'conceal',
#   'circumstances',
#   'cylindrically',
#   'camcorder',
#   'coupons',
#   'categorises',
#   'colossally',
#   'considerable',
#   'chauffeur',
#   'cadences',
#   'chiropractic',
#   'companionable',
#   'cant',
#   'campuses',
#   'clocked',
#   'caw',
#   'creationist',
#   'constantly',
#   'citron',
#   'chivalric',
#   'censer',
#   'cloying',
#   'coping',
#   'casualness',
#   'collins',
#   'clubfooted',
#   'classifiable',
#   'crises',
#   'chancer',
#   'crossreferenced',
#   'contracts',
#   'chagrined',
#   'clemency',
#   'criminological',
#   'chastise',
#   'constructive',
#   'criticise',
#   'crystallographic',
#   'clique',
#   'chatters',
#   'chicks',
#   'communal',
#   'caracal',
#   'chastising',
#   'counteracted',
#   'coquettes',
#   'croft',
#   'chairpersons',
#   'contribute',
#   'cordoned',
#   'costings',
#   'challenger',
#   'contrasting',
#   'creakier',
#   'conflictingly',
#   'classification',
#   'costlier',
#   'coaxing',
#   'compilable',
#   'coiners',
#   'codifying',
#   'coterie',
#   'creased',
#   'cane',
#   'concurrency',
#   'corpses',
#   'contemplative',
#   'collapsed',
#   'canary',
#   'cancelling',
#   'cleanser',
#   'claustrophobia',
#   'candid',
#   'conciliate',
#   'chanciest',
#   'cratered',
#   'crisps',
#   'chant',
#   'centenary',
#   'crannies',
#   'cowing',
#   'charmers',
#   'consanguineous',
#   'counterproductive',
#   'confidants',
#   'consumed',
#   'carnivals',
#   'castling',
#   'commutes',
#   'chlorofluorocarbon',
#   'connivance',
#   'corticosteroids',
#   'circumspect',
#   'constituent',
#   'circlet',
#   'cawing',
#   'cocktail',
#   'confusedly',
#   'crewed',
#   'conjoined',
#   'conciseness',
#   'carvers',
#   'cretans',
#   'crediting',
#   'crusty',
#   'clucked',
#   'calorimeters',
#   'crucifix',
#   'chronology',
#   'commencement',
#   'contoured',
#   'corneal',
#   'customisation',
#   'caterwaul',
#   'care',
#   'carvings',
#   'complaining',
#   'coxcomb',
#   'charles',
#   'coloure',
#   'connections',
#   'construction',
#   'caucus',
#   'constitutionally',
#   'crushingly',
#   'churchmen',
#   'croup',
#   'chiropody',
#   'cherryred',
#   'catalyst',
#   'correlation',
#   'compressed',
#   'calibre',
#   'clicking',
#   'convulsively',
#   'constitution',
#   'cur',
#   'clarifications',
#   'coffins',
#   'culvert',
#   'candidates',
#   'concocted',
#   'cradled',
#   'campsites',
#   'curb',
#   'certificates',
#   'censorship',
#   'captain',
#   'clams',
#   'commanded',
#   'constricts',
#   'cerebellum',
#   'coheres',
#   'cliches',
#   'captives',
#   'comprises',
#   'confiscates',
#   'clicked',
#   'colours',
#   'commenced',
#   'complain',
#   'canines',
#   'copulation',
#   'chroniclers',
#   'certificated',
#   'cods',
#   'concession',
#   'concentrator',
#   'cork',
#   'courtship',
#   'cleg',
#   'camping',
#   'cookbook',
#   'calico',
#   'cultivar',
#   'chancellery',
#   'crofting',
#   'circadian',
#   'consensual',
#   'collinear',
#   'churchyards',
#   'collectivisation',
#   'containment',
#   'cyprians',
#   'commits',
#   'chaperones',
#   'conceivably',
#   'childishly',
#   'conceive',
#   'cropped',
#   'capacitance',
#   'carbohydrate',
#   'chorused',
#   'candies',
#   'clambering',
#   'caress',
#   'candidacy',
#   'contemptibly',
#   'crosser',
#   'castrato',
#   'custodianship',
#   'centenarians',
#   'casuistry',
#   'creations',
#   'cleat',
#   'choughs',
#   'coxcombs',
#   'crept',
#   'coo',
#   'cadet',
#   'convecting',
#   'crosses',
#   'clipboards',
#   'celebratory',
#   'cuds',
#   'cardinal',
#   'concise',
#   'coalesce',
#   'competitively',
#   'centimetres',
#   'centrally',
#   'cynics',
#   'counting',
#   'changeable',
#   'centre',
#   'cajoled',
#   'cameraman',
#   'cyclical',
#   'caprices',
#   'cacophonous',
#   'cannoning',
#   'cheeking',
#   'captions',
#   'cairo',
#   'crone',
#   'connoisseurs',
#   'citation',
#   'covariances',
#   'childproof',
#   'caftans',
#   'culprit',
#   'crammer',
#   'cade',
#   'caretaker',
#   'colonnade',
#   'corespondent',
#   'capitalist',
#   'cleanness',
#   'chlorinated',
#   'cravats',
#   'curvy',
#   'commodities',
#   'cob',
#   'coproduced',
#   'chafe',
#   'counterfoil',
#   'chorals',
#   'clarity',
#   'coronation',
#   'commute',
#   'clamouring',
#   'counterattacks',
#   'concatenates',
#   'cavein',
#   'congratulating',
#   'clapping',
#   'coherence',
#   'crick',
#   'chirp',
#   'circumcised',
#   'cackles',
#   'clay',
#   'cab',
#   'convocation',
#   'cupid',
#   'conversationalists',
#   'cobblestones',
#   'crashing',
#   'cox',
#   'continuations',
#   'circuses',
#   'capitalists',
#   'caches',
#   'capability',
#   'compellingly',
#   'controlling',
#   'cares',
#   'configuration',
#   'chore',
#   'classically',
#   'counterrevolutionaries',
#   'counselling',
#   'corduroys',
#   'circumventing',
#   'covets',
#   'climatically',
#   'chairs',
#   'cradle',
#   'cabman',
#   'crewman',
#   'comments',
#   'customisations',
#   'categorical',
#   'celeriac',
#   'creosote',
#   'consumptive',
#   'curtsies',
#   'coruscates',
#   'curving',
#   'confuse',
#   'commendable',
#   'curvature',
#   'concatenated',
#   'conceives',
#   'coalminers',
#   'cruller',
#   'conquests',
#   'calumnies',
#   'concessional',
#   'counterintelligence',
#   'cleans',
#   'carriageway',
#   'civics',
#   'camelot',
#   'carton',
#   'conscious',
#   'claims',
#   'chantry',
#   'craning',
#   'cuss',
#   'caging',
#   'conservation',
#   'controls',
#   'curses',
#   'constants',
#   'compromises',
#   'codification',
#   'chalets',
#   'chaplains',
#   'citrate',
#   'convulsing',
#   'correlate',
#   'circularise',
#   'curtain',
#   'cordate',
#   'coordination',
#   'charlady',
#   'civilisation',
#   'constipation',
#   'castor',
#   'concentration',
#   'canoeist',
#   'coffers',
#   'contested',
#   'cutting',
#   'cervix',
#   'conkers',
#   'chauvinism',
#   'choreographing',
#   'crystallise',
#   'chunk',
#   'crumby',
#   'cheated',
#   'cress',
#   'chiseled',
#   'consoling',
#   'copy',
#   'civilities',
#   'cantered',
#   'cathodes',
#   'comprehensibility',
#   'climbdown',
#   'chemists',
#   'curdled',
#   'cowering',
#   'cudgel',
#   'culture',
#   'congregations',
#   'chapters',
#   'conurbation',
#   'concerts',
#   'creoles',
#   'countersign',
#   'correlated',
#   'crumbliest',
#   'copra',
#   'curled',
#   'covenants',
#   'consent',
#   'cancels',
#   'condoled',
#   'cylindrical',
#   'captivating',
#   'cedilla',
#   'cases',
#   'centimes',
#   'compendiums',
#   'crouch',
#   'carcass',
#   'cutout',
#   'curtailed',
#   'consecration',
#   'cued',
#   'condoning',
#   'contentedly',
#   'carbonise',
#   'chimpanzees',
#   'cellulite',
#   'codeword',
#   'cans',
#   'confidant',
#   'contortionist',
#   'curs',
#   'chimes',
#   'challenging',
#   'crete',
#   'cassettes',
#   'confluence',
#   'conditioner',
#   'confessionals',
#   'corridors',
#   'circulated',
#   'cocaine',
#   'clucks',
#   'concentrate',
#   'cheat',
#   'cure',
#   'circulatory',
#   'cohered',
#   'culpable',
#   'contingently',
#   'centraliser',
#   'conciliar',
#   'conveyor',
#   'coronet',
#   'contraindications',
#   'chemicals',
#   'cobbling',
#   'constructable',
#   'collarless',
#   'courier',
#   'cooking',
#   'convalescence',
#   'chilean',
#   'cockatrices',
#   'commission',
#   'camber',
#   'conformational',
#   'cordials',
#   'cheery',
#   'calculable',
#   'customs',
#   'collating',
#   'checks',
#   'chameleons',
#   'constrict',
#   'cowritten',
#   'capitulating',
#   'condemns',
#   'cartons',
#   'chastened',
#   'chubby',
#   'cabs',
#   'crocodile',
#   'caper',
#   'capering',
#   'cherish',
#   'cheerleader',
#   'conceived',
#   'computing',
#   'contenting',
#   'cannel',
#   'congregational',
#   'conversation',
#   'columnist',
#   'cowgirl',
#   'cockiest',
#   'commonsensical',
#   'changes',
#   'criminalise',
#   'court',
#   'coelenterates',
#   'chainsmoke',
#   'cytoplasmic',
#   'charismatic',
#   'consuls',
#   'compendium',
#   'controvert',
#   'cumulatively',
#   'consisting',
#   'change',
#   'caymans',
#   'cancer',
#   'coronaries',
#   'cooper',
#   'clairvoyant',
#   'catharsis',
#   'cocktails',
#   'crier',
#   'cuff',
#   'cluttered',
#   'consuming',
#   'corsica',
#   'cogs',
#   'collocation',
#   'cryogenic',
#   'cleverer',
#   'conflicting',
#   'crossed',
#   'collapsible',
#   'circularised',
#   'cowers',
#   'centralising',
#   'cohere',
#   'calcified',
#   'comparisons',
#   'chieftain',
#   'crevices',
#   'championed',
#   'compasses',
#   'centralises',
#   'consume',
#   'corps',
#   'contradict',
#   'convince',
#   'caveats',
#   'contextually',
#   'chimaerical',
#   'crucible',
#   'castaway',
#   'choppier',
#   'coaching',
#   'carving',
#   'catalogues',
#   'covetousness',
#   'candle',
#   'cloaca',
#   'coils',
#   'centrality',
#   'commend',
#   'cheesy',
#   'conqueror',
#   'childlike',
#   'cartoons',
#   'could',
#   'contributors',
#   'catapults',
#   'cine',
#   'cypriots',
#   'consents',
#   'continua',
#   'confers',
#   'changeling',
#   'concuss',
#   'cytology',
#   'caprice',
#   'calibrator',
#   'classmate',
#   'crashland',
#   'chairlift',
#   'concoctions',
#   'classy',
#   'championship',
#   'cents',
#   'complementing',
#   'classlessness',
#   'centrifuged',
#   'conductor',
#   'carbuncles',
#   'catched',
#   'croziers',
#   'come',
#   'contrasts',
#   'creative',
#   'conductive',
#   'casserole',
#   'conmen',
#   'cooker',
#   'crawling',
#   'computation',
#   'chequerboard',
#   'cartridges',
#   'chums',
#   'courted',
#   'contemplates',
#   'configure',
#   'cagoule',
#   'creamer',
#   'corpora',
#   'contrariwise',
#   'contentious',
#   'choker',
#   'creeds',
#   'carroty',
#   'countess',
#   'chivvy',
#   'couplings',
#   'chasing',
#   'coasts',
#   'chronicle',
#   'caldron',
#   'capitalises',
#   'confederations',
#   'car',
#   'cleaved',
#   'cruisers',
#   'chaps',
#   'cornucopia',
#   'concords',
#   'cavalryman',
#   'cuddly',
#   'coagulated',
#   'curls',
#   'corrupts',
#   'creditors',
#   'cite',
#   'choppiest',
#   'comply',
#   'choppy',
#   'congratulations',
#   'classified',
#   'comfortingly',
#   'cerebral',
#   'communicator',
#   'counteracts',
#   'coauthored',
#   'certify',
#   'corrosive',
#   'chewing',
#   'crucial',
#   'convictions',
#   'cerise',
#   'curvaceous',
#   'cherries',
#   'coerce',
#   'cash',
#   'carting',
#   'cute',
#   'crematorium',
#   'confidential',
#   'coprocessor',
#   'carbines',
#   'crafting',
#   'colourisation',
#   'catatonic',
#   'canisters',
#   'condense',
#   'cowherd',
#   'calls',
#   'cholesterol',
#   'cop',
#   'contravenes',
#   'convoys',
#   'composed',
#   'confusions',
#   'cyberspace',
#   'cruncher',
#   'confinements',
#   'capitol',
#   'cloudiest',
#   'chirping',
#   'cowboy',
#   'catchy',
#   'contravene',
#   'consciously',
#   'convective',
#   'carelessly',
#   'crucifixes',
#   'chemical',
#   'conductivities',
#   'clearances',
#   'childish',
#   'cudgels',
#   'course',
#   'constraining',
#   'cladding',
#   'cheeked',
#   'contrivances',
#   'connoted',
#   'cretan',
#   'capitation',
#   'crotchet',
#   'conditions',
#   'conflict',
#   'compulsions',
#   'camp',
#   'capsules',
#   'countdown',
#   'caricature',
#   'censuring',
#   'cuddliest',
#   'conforming',
#   'constructions',
#   'copulate',
#   'crudities',
#   'chink',
#   'cheekiest',
#   'clergymen',
#   'cyclically',
#   'coincidental',
#   'cuttings',
#   'competitor',
#   'city',
#   'contiguity',
#   'cam',
#   'cryptographically',
#   'critiques',
#   'crystalline',
#   'coaster',
#   'coordinator',
#   'collective',
#   'covers',
#   'concerned',
#   'cocking',
#   'coma',
#   'craft',
#   'canonise',
#   'colostomies',
#   'cooks',
#   'canapes',
#   'checkpoints',
#   'compares',
#   'ceres',
#   'cameras',
#   'cruising',
#   'carding',
#   'challenged',
#   'chintzy',
#   'consultancies',
#   'coming',
#   'chortled',
#   'cordage',
#   'concessions',
#   'copyist',
#   'construing',
#   'contralto',
#   'cube',
#   'cogitate',
#   'constriction',
#   'communication',
#   'computer',
#   'countermanded',
#   'classifier',
#   'conjunct',
#   'congruent',
#   'cushions',
#   'corralled',
#   'croatia',
#   'consorted',
#   'chinless',
#   'casters',
#   'cryings',
#   'cultivations',
#   'cliffs',
#   'captor',
#   'columnar',
#   'cone',
#   'cloak',
#   'coquettishly',
#   'conflicts',
#   'censor',
#   'cochlear',
#   'conflictual',
#   'conducting',
#   'collies',
#   'courtly',
#   'coordinated',
#   'conceit',
#   'completing',
#   'cumulative',
#   'chlorophyll',
#   'chuff',
#   'chopping',
#   'communicating',
#   'capitulation',
#   'cohabitation',
#   'concordant',
#   'chamber',
#   'caster',
#   'colonisation',
#   'conversing',
#   'counterfeiters',
#   'collaborating',
#   'chromite',
#   'craftily',
#   'clarifying',
#   'coquette',
#   'collectability',
#   'cornets',
#   'currents',
#   'crores',
#   'comestible',
#   'catalysing',
#   'clinically',
#   'cockle',
#   'colonist',
#   'captivated',
#   'consciousnesses',
#   'crazier',
#   'coacted',
#   'communicated',
#   'clanged',
#   'copiously',
#   'curlers',
#   'cunning',
#   'clout',
#   'crowbars',
#   'cart',
#   'canings',
#   'cavalrymen',
#   'crayoned',
#   'cylinder',
#   'crystallised',
#   'cresting',
#   'complacency',
#   'cabin',
#   'choreographers',
#   'chair',
#   'combinatorial',
#   'chessmen',
#   'couching',
#   'conundrums',
#   'cheques',
#   'citations',
#   'crasser',
#   'celebrities',
#   'consenting',
#   'census',
#   'creeps',
#   'convicts',
#   'constitutes',
#   'courtyard',
#   'coarseness',
#   'cheapen',
#   'crucifiable',
#   'crisis',
#   'clothed',
#   'cram',
#   'cicadas',
#   'childminders',
#   'corroborated',
#   'cabriolet',
#   'canticle',
#   'clutching',
#   ...],
#  'd': ['despising',
#   'dwindle',
#   'definitional',
#   'december',
#   'dunked',
#   'despondent',
#   'drunkard',
#   'drownings',
#   'drawbridge',
#   'demists',
#   'depositories',
#   'devoid',
#   'disability',
#   'disintegrates',
#   'dishcloth',
#   'diffracting',
#   'dahlias',
#   'destroyable',
#   'demoted',
#   'dislike',
#   'disturbances',
#   'derails',
#   'dribble',
#   'diplexers',
#   'demonstrator',
#   'destitute',
#   'drowsiness',
#   'diadem',
#   'dramatise',
#   'disregarded',
#   'dreamier',
#   'dispirited',
#   'domestics',
#   'decomposed',
#   'draws',
#   'discern',
#   'detain',
#   'dramatics',
#   'decryption',
#   'distilled',
#   'deliciously',
#   'dispatching',
#   'dweller',
#   'decimating',
#   'dereliction',
#   'dolerite',
#   'disaffiliate',
#   'duckbilled',
#   'duchies',
#   'despoiled',
#   'dons',
#   'discrepancy',
#   'deviousness',
#   'draughtsman',
#   'dotting',
#   'diaphragms',
#   'dehorn',
#   'disseminate',
#   'dieselelectric',
#   'diapers',
#   'devastating',
#   'decade',
#   'discordance',
#   'drooling',
#   'dawdle',
#   'defiling',
#   'donor',
#   'dissenters',
#   'desperado',
#   'doesnt',
#   'dualities',
#   'deepfreeze',
#   'delimiters',
#   'disputation',
#   'distempers',
#   'departs',
#   'devourer',
#   'disorientated',
#   'diatonic',
#   'despair',
#   'disarranging',
#   'discriminant',
#   'diaphanous',
#   'dare',
#   'direst',
#   'decors',
#   'dignify',
#   'drifting',
#   'descendants',
#   'deputed',
#   'depose',
#   'deodorants',
#   'drawings',
#   'dressmakers',
#   'drawable',
#   'disposing',
#   'dislodging',
#   'discomfited',
#   'dissects',
#   'deforming',
#   'devotional',
#   'disparagement',
#   'desirable',
#   'defusing',
#   'deepness',
#   'distinguishable',
#   'declaims',
#   'digitise',
#   'droopingly',
#   'dermatological',
#   'diagonals',
#   'describable',
#   'densities',
#   'details',
#   'discotheques',
#   'dissipation',
#   'degree',
#   'desolating',
#   'detaching',
#   'dregs',
#   'dismissive',
#   'daddies',
#   'deploy',
#   'disrupted',
#   'downside',
#   'democrats',
#   'demonstrably',
#   'detonations',
#   'darned',
#   'deifying',
#   'discord',
#   'devotedness',
#   'digressing',
#   'deface',
#   'daughterinlaw',
#   'disulphide',
#   'disfigures',
#   'debenture',
#   'damped',
#   'doses',
#   'daemonic',
#   'deeds',
#   'deeprooted',
#   'dramatic',
#   'descriptor',
#   'distillate',
#   'downtrodden',
#   'depicted',
#   'dismembers',
#   'decline',
#   'deconstructive',
#   'distances',
#   'duty',
#   'degrease',
#   'debilitating',
#   'desirably',
#   'deliriously',
#   'dyslexics',
#   'deuce',
#   'denigrating',
#   'delinquency',
#   'decompositions',
#   'diminishable',
#   'deadend',
#   'deploys',
#   'differences',
#   'demographically',
#   'dances',
#   'disgustingly',
#   'dubious',
#   'decimal',
#   'decease',
#   'disparaged',
#   'diametrically',
#   'declaring',
#   'deviate',
#   'deformity',
#   'dehumidifier',
#   'divinest',
#   'diagonally',
#   'disfranchise',
#   'diciest',
#   'disable',
#   'danceable',
#   'declension',
#   'depressingly',
#   'decays',
#   'deafened',
#   'disrepute',
#   'dummies',
#   'description',
#   'disinclined',
#   'dosing',
#   'dragged',
#   'decapod',
#   'deficits',
#   'dames',
#   'dilettante',
#   'dancer',
#   'disjunction',
#   'disband',
#   'dimensioning',
#   'dispatches',
#   'dumbbell',
#   'discotheque',
#   'disaggregation',
#   'dull',
#   'debuggers',
#   'delete',
#   'discernible',
#   'dong',
#   'drudges',
#   'deaconesses',
#   'demarcating',
#   'dumplings',
#   'deification',
#   'dint',
#   'dietician',
#   'districts',
#   'dithers',
#   'distractedness',
#   'distrusts',
#   'discoveries',
#   'divergence',
#   'deposition',
#   'deviates',
#   'disputing',
#   'dilute',
#   'dream',
#   'doubt',
#   'dyestuffs',
#   'destruct',
#   'deluges',
#   'dutifulness',
#   'downfall',
#   'directive',
#   'dyeings',
#   'daubed',
#   'deanery',
#   'daylong',
#   'delegates',
#   'dipsomaniac',
#   'detectives',
#   'denuded',
#   'discharge',
#   'deepen',
#   'dismay',
#   'dizzier',
#   'devils',
#   'decilitre',
#   'distributes',
#   'dispelled',
#   'disgruntled',
#   'drips',
#   'dissociate',
#   'dolly',
#   'directory',
#   'droopier',
#   'different',
#   'disabilities',
#   'drastically',
#   'decorators',
#   'dissected',
#   'decor',
#   'denominational',
#   'discography',
#   'dissented',
#   'desirability',
#   'divorced',
#   'dopier',
#   'dapple',
#   'denude',
#   'disestablishment',
#   'draughtsmanship',
#   'deceitfulness',
#   'dooming',
#   'deceptive',
#   'derivable',
#   'dusky',
#   'damage',
#   'disrupt',
#   'dingle',
#   'detained',
#   'downgrade',
#   'despicably',
#   'dozen',
#   'denizens',
#   'desirabilia',
#   'dacha',
#   'deepening',
#   'dissuade',
#   'deplete',
#   'delusions',
#   'dauphin',
#   'dessicated',
#   'derisive',
#   'decode',
#   'dirigible',
#   'daze',
#   'digests',
#   'debater',
#   'drunkenly',
#   'disincentives',
#   'deliquescent',
#   'discontinuously',
#   'divisors',
#   'daniel',
#   'degaussed',
#   'devilment',
#   'discriminatory',
#   'darted',
#   'duller',
#   'detainer',
#   'disciplinary',
#   'dismissed',
#   'denier',
#   'drone',
#   'decreasing',
#   'dominated',
#   'delict',
#   'duplicitous',
#   'detainees',
#   'diffracted',
#   'diffident',
#   'diktat',
#   'destinies',
#   'delayed',
#   'disembarking',
#   'delivered',
#   'degeneracy',
#   'dockside',
#   'delicatessens',
#   'dracone',
#   'decompression',
#   'detonators',
#   'delimiter',
#   'dejects',
#   'doorway',
#   'demount',
#   'demonstratively',
#   'derangement',
#   'disembowels',
# ...
#   'widens',
#   'wirier',
#   'worryingly',
#   'weary',
#   'worn',
#   'whence',
#   'woodlands',
#   'waveforms',
#   'wafers',
#   'wilt',
#   'worships',
#   'watermelon',
#   'watchable',
#   'wordsmith',
#   'wear',
#   'wagon',
#   'warrior',
#   'wholemeal',
#   'wink',
#   'workman',
#   'waitresses',
#   'wold',
#   'watered',
#   'whippy',
#   'wedges',
#   'wigeons',
#   'westerners',
#   'windows',
#   'wining',
#   'wellbred',
#   'without',
#   'whites',
#   'watchful',
#   'wholefood',
#   'wherewithal',
#   'wed',
#   'wastes',
#   'weakening',
#   'wolfed',
#   'windmills',
#   'wasting',
#   'welldesigned',
#   'waxen',
#   'wax',
#   'wishfully',
#   'waterholes',
#   'willingness',
#   'warranty',
#   'widely',
#   'willing',
#   'wasteful',
#   'weather',
#   'withstand',
#   'welloff',
#   'waggery',
#   'woodbine',
#   'wooded',
#   'watchword',
#   'where',
#   'welts',
#   'we',
#   'weightlessly',
#   'whiteness',
#   'wellmarked',
#   'whorehouse',
#   'wrapped',
#   'witter',
#   'waver',
#   'witness',
#   'worry',
#   'ward',
#   'washerwoman',
#   'wiring',
#   'weakling',
#   'wreaked',
#   'warming',
#   'waifs',
#   'whatsoever',
#   'wellfed',
#   'while',
#   'wearily',
#   'warplanes',
#   'were',
#   'widows',
#   'workday',
#   'wholegrain',
#   'westerner',
#   'wicked',
#   'workout',
#   'whiplash',
#   'whitewashing',
#   'waterproofs',
#   'winnable',
#   'whom',
#   'warlocks',
#   'wellchosen',
#   'worked',
#   'wittily',
#   'wrapping',
#   'woollier',
#   'whispered',
#   'whereabouts',
#   'watchman',
#   'wellstructured',
#   'wailed',
#   'weeded',
#   'wisely',
#   'weedy',
#   'warehouse',
#   'washy',
#   'wolfhounds',
#   'wheeler',
#   'watercolour',
#   'wigs',
#   'weirdest',
#   'warmheartedness',
#   'watering',
#   'wit',
#   'whetstone',
#   'woken',
#   'wrongfully',
#   'wettest',
#   'whiff',
#   'workmen',
#   'walks',
#   'weightlifter',
#   'worms',
#   'whop',
#   'wormy',
#   'whizz',
#   'withdrawn',
#   'worshipper',
#   'wrack',
#   'wiped',
#   'waltzed',
#   'weeping',
#   'welter',
#   'wellkept',
#   'waistcoat',
#   'wodan',
#   'wrens',
#   'weedier',
#   'wallet',
#   'wandered',
#   'weakness',
#   'workhouses',
#   'wirer',
#   'waffle',
#   'wastelands',
#   'werewolf',
#   'waved',
#   'wringing',
#   'warblers',
#   'waggles',
#   'wrestled',
#   'wiles',
#   'wilfulness',
#   'wending',
#   'windfalls',
#   'watchtower',
#   'wolds',
#   'wayward',
#   'wainscot',
#   'watchmaker',
#   'withdrew',
#   'weightlifting',
#   'wriggly',
#   'wristband',
#   'wildcats',
#   'wildlife',
#   'wondering',
#   'wagered',
#   'weaning',
#   'weird',
#   'windowing',
#   'wrecker',
#   'wreckers',
#   'wined',
#   'wheelers',
#   'weeper',
#   'wellbehaved',
#   'wellhead',
#   'witchhunts',
#   'waterlogged',
#   'weasels',
#   'wasp',
#   'walruses',
#   'wildest',
#   'windbags',
#   'whey',
#   'wistfully',
#   'warthog',
#   'wiggles',
#   'wraparound',
#   'wildness',
#   'wellborn',
#   'wobbliest',
#   'weakly',
#   'weekenders',
#   'wellpaid',
#   'wicketkeeping',
#   'waft',
#   'waxed',
#   'witchcraft',
#   'wholly',
#   'waveguides',
#   'weathercock',
#   'warbler',
#   'what',
#   'weightily',
#   'wallchart',
#   'wallabies',
#   'wetsuit',
#   'wallop',
#   'wonder',
#   'whale',
#   'wholesomeness',
#   'whichever',
#   'wench',
#   'wisecracks',
#   'woos',
#   'withdrawing',
#   'waxworks',
#   'whisk',
#   'wrinkles',
#   'written',
#   'workforce',
#   'windowshop',
#   'wart',
#   'whereas',
#   'wintrier',
#   'wholesaler',
#   'wheals',
#   'wood',
#   'west',
#   'wrangler',
#   'winging',
#   'waxwork',
#   'whimper',
#   'whitewash',
#   'win',
#   'write',
#   'warmers',
#   'wellplaced',
#   'weld',
#   'webbed',
#   'workmanlike',
#   'wellgrounded',
#   'worthless',
#   'wallets',
#   'wisp',
#   'wantonness',
#   'wails',
#   'website',
#   'wrongdoer',
#   'workforces',
#   'weediest',
#   'worthies',
#   'wherry',
#   'wronging',
#   'westernised',
#   'wheeled',
#   'wasteland',
#   'with',
#   'watercooled',
#   'welshman',
#   'wellsupported',
#   'watchers',
#   'worldliness',
#   'warsaw',
#   'whiskery',
#   'windbreak',
#   'weatherbeaten',
#   'wartime',
#   'wounds',
#   'wallflowers',
#   'warlock',
#   'waterproofing',
#   'wafer',
#   'workloads',
#   'wardens',
#   'whitish',
#   'wireless',
#   'wheelhouse',
#   'warships',
#   'wraith',
#   'was',
#   'whitener',
#   'wavered',
#   'waned',
#   'wicket',
#   'wilful',
#   'wimple',
#   'warmly',
#   'whitened',
#   'wipers',
#   'waddle',
#   'wipes',
#   'womaniser',
#   'wallow',
#   'wasters',
#   'wither',
#   'warps',
#   'wellordered',
#   'waffles',
#   'workshy',
#   'whips',
#   'wellrounded',
#   'watercourse',
#   'workstations',
#   'witchhunt',
#   'wolfishly',
#   'wools',
#   'whisper',
#   'whirled',
#   'wholeness',
#   'weightlifters',
#   'woollen',
#   'whacked',
#   'whiteboards',
#   'witnessing',
#   'wagtails',
#   'wracked',
#   'windscreen',
#   'whirr',
#   'weirdo',
#   'wakes',
#   'wording',
#   'wrappings',
#   'wrenching',
#   'wavebands',
#   'wages',
#   'warred',
#   'wellthoughtout',
#   'woodshed',
#   'winged',
#   'wealthier',
#   'wallpapers',
#   'watermelons',
#   'wackier',
#   'wedlock',
#   'whatnot',
#   'windsurfing',
#   'whereby',
#   'wariest',
#   'ween',
#   'welds',
#   'warring',
#   'washington',
#   'wellworn',
#   'wizened',
#   'waning',
#   'wander',
#   'wreak',
#   'wind',
#   'windless',
#   'wattage',
#   'watchtowers',
#   'wishful',
#   'wren',
#   'wash',
#   'woodenly',
#   'wows',
#   'wavings',
#   'whitebait',
#   'wanders',
#   'washable',
#   'wretchedly',
#   'welldefined',
#   'walkabout',
#   'weeklies',
#   'warmer',
#   'wordlessly',
#   'whispers',
#   'weighbridge',
#   'warmonger',
#   'warriors',
#   'winches',
#   'wrathfully',
#   'web',
#   'weathering',
#   'weep',
#   'wiriest',
#   'walled',
#   'wresting',
#   'wrinkly',
#   'worldly',
#   'whirred',
#   'wintriest',
#   'winter',
#   'weakish',
#   'winder',
#   'warbling',
#   'watchfully',
#   'whaling',
#   'whirring',
#   'waltzes',
#   'weakens',
#   'waiting',
#   'workpeople',
#   'welterweight',
#   'wavers',
#   'waverers',
#   'workhorse',
#   'well',
#   'warms',
#   'wheelbarrows',
#   'whiskies',
#   'woodpeckers',
#   'weaves',
#   'waterbeds',
#   'winked',
#   'wellprepared',
#   'wallpapering',
#   'working',
#   'watery',
#   'warranted',
#   'wets',
#   'weightiest',
#   'warding',
#   'wraps',
#   'widowhood',
#   'waterway',
#   'woke',
#   'writs',
#   'wrist',
#   'wright',
#   'woodcutters',
#   'weekly',
#   'woofer',
#   'waterglass',
#   'wondrous',
#   'which',
#   'wrasse',
#   'warn',
#   'workpieces',
#   'wok',
#   'workmates',
#   'wretch',
#   'whiten',
#   'withholding',
#   'wont',
#   'welders',
#   'workroom',
#   'whippet',
#   'womankind',
#   'whaler',
#   'wanted',
#   'watercourses',
#   'waggled',
#   'wordplay',
#   'welfare',
#   'woodsman',
#   'wormholes',
#   'wrest',
#   'worriers',
#   'whee',
#   'windcheater',
#   'wellorganised',
#   'worshipping',
#   'waded',
#   'wronger',
#   'waterfowl',
#   'witless',
#   'waterways',
#   'wedging',
#   'why',
#   'webs',
#   'weightlessness',
#   'winkled',
#   'workspace',
#   'wavelength',
#   'workhouse',
#   'wonderfulness',
#   'windsock',
#   'willynilly',
#   'wallflower',
#   'wiser',
#   'warmed',
#   'wrongest',
#   'windfall',
#   'waters',
#   'worksheet',
#   'wished',
#   'worrier',
#   'warpath',
#   'wooly',
#   'wrists',
#   'winsome',
#   'westwards',
#   'waterfront',
#   'walnuts',
#   'winners',
#   'welltodo',
#   'washstand',
#   'waring',
#   'wheelchairs',
#   'wharfs',
#   'woodlouse',
#   'whimsically',
#   'wisps',
#   'wakens',
#   'wheelbarrow',
#   'wherein',
#   'withering',
#   'whalebone',
#   'whiting',
#   'waives',
#   'washbasins',
#   'whipping',
#   'wellspoken',
#   'walkway',
#   'wellloved',
#   'woks',
#   'wield',
#   'watermark',
#   'wilted',
#   'whosoever',
#   'windowed',
#   'wetting',
#   'waken',
#   'wolfwhistles',
#   'winking',
#   'watermen',
#   'whereon',
#   'warfare',
#   'writing',
#   'world',
#   'weedkillers',
#   'wounded',
#   'woods',
#   'woodwind',
#   'woodwork',
#   'waistband',
#   'wellmatched',
#   'whinnied',
#   'weekdays',
#   'weatherman',
#   'withstands',
#   'wall',
#   'wrinkle',
#   'weddings',
#   'wane',
#   'walnut',
#   'wetly',
#   'wife',
#   'welltimed',
#   'wreathes',
#   'wintery',
#   'wakened',
#   'war',
#   'wellbeing',
#   'wickets',
#   'wetter',
#   'warrants',
#   'wordiness',
#   'watched',
#   'worthlessness',
#   'whir',
#   'warhorse',
#   'warehousing',
#   'workfare',
#   'wharf',
#   'wittering',
#   'wordings',
#   'workhorses',
#   'warmness',
#   'waveband',
#   'wheaten',
#   'watercolourists',
#   'would',
#   'winced',
#   'won',
#   'wonderland',
#   'widen',
#   'wreck',
#   'winner',
#   'wastrel',
#   'workaday',
#   'watermill',
#   'wan',
#   'wayside',
#   'wringer',
#   'wigeon',
#   'webbing',
#   'westerns',
#   'whittle',
#   'waggle',
#   'worthily',
#   'wayout',
#   'whorled',
#   'woollike',
#   'wanton',
#   'windowshopping',
#   'worthiest',
#   'wave',
#   'writhe',
#   'whine',
#   'woodworkers',
#   'wishes',
#   'waterskiing',
#   'wailer',
#   'wrings',
#   'westerly',
#   'welly',
#   'weaklings',
#   'washbasin',
#   'wettable',
#   'wooer',
#   'whitening',
#   'womanly',
#   'wellendowed',
#   'whiskeys',
#   'watersheds',
#   'woodpile',
#   'wail',
#   'western',
#   'welt',
#   'waspwaisted',
#   'wheezed',
#   'wish',
#   'wildcat',
#   'workshop',
#   'wrestles',
#   'walkietalkies',
#   'welladjusted',
#   'wainscoting',
#   'wipe',
#   'worried',
#   'wafts',
#   'wigwam',
#   'wetlands',
#   'watertable',
#   'wickedest',
#   'whet',
#   'wheedle',
#   'whizzkid',
#   'wildeyed',
#   'workable',
#   'wideeyed',
#   'waterless',
#   'wraths',
#   'wires',
#   'watershed',
#   'wrecked',
#   'wrongness',
#   'wordy',
#   'wolfhound',
#   'workless',
#   'watcher',
#   'widowed',
#   'whistle',
#   'waveform',
#   'worthwhile',
#   'wordier',
#   'weans',
#   'winnow',
#   'whooping',
#   'wellbalanced',
#   'wryness',
#   'whither',
#   'waffled',
#   'wormhole',
#   'widower',
#   'waster',
#   'waviest',
#   'warlords',
#   'wrathful',
#   'watchmen',
#   'wiliest',
#   'wobbly',
#   'waits',
#   'workbook',
#   'whoop',
#   'waterside',
#   'white',
#   'warder',
#   'whereto',
#   'wheelie',
#   'wardrobes',
#   'windlass',
#   'wellington',
#   'watts',
#   'whist',
#   'weaving',
#   'winding',
#   'wriggle',
#   'windsurfer',
#   'warners',
#   'wrested',
#   'wrong',
#   'wriggled',
#   'wandering',
#   'wheat',
#   'wellbeloved',
#   'woodcut',
#   'whistled',
#   'woman',
#   'watches',
#   'waggoners',
#   'woolly',
#   'wasps',
#   'womanising',
#   'windsurf',
#   'wheelbase',
#   'workbooks',
#   'winnings',
#   'worst',
#   'woodman',
#   'walk',
#   'whippets',
#   'whetstones',
#   'wagers',
#   'wales',
#   'werewolves',
#   'wombs',
#   'webby',
#   'warmblooded',
#   'worries',
#   'wisdom',
#   'withheld',
#   'watching',
#   'wade',
#   'witnesses',
#   'wags',
#   'welldeveloped',
#   'windswept',
#   'waterproofed',
#   'wanderers',
#   'watertight',
#   'wharves',
#   'wagtail',
#   'warranties',
#   'whap',
#   'whomsoever',
#   'wapiti',
#   'wove',
#   'warped',
#   'wrongs',
#   'weaselly',
#   'wolf',
#   'wellfounded',
#   'wellconnected',
#   'windier',
#   'wrinkling',
#   'wreaking',
#   'wafture',
#   'weirdness',
#   'weirdly',
#   'wherefores',
#   'waxing',
#   'wriggles',
#   'warty',
#   'wilting',
#   'wiggler',
#   'whimpered',
#   'winters',
#   'wittingly',
#   'whirligig',
#   'wanting',
#   'whim',
#   'wallowed',
#   'wage',
#   'wizard',
#   'weathercocks',
#   'writhed',
#   'warns',
#   'wherefore',
#   'worsened',
#   'weeks',
#   'wavering',
#   'weir',
#   'wrapper',
#   'whores',
#   'wearable',
#   'waterproof',
#   'wondrously',
#   'waked',
#   'woodmen',
#   'wadis',
#   'welling',
#   'wobbling',
#   'winces',
#   'walling',
#   'waiver',
#   'wrongdoers',
#   'waddled',
#   'wreaths',
#   'waterloo',
#   'wicketkeeper',
#   'weakest',
#   'writable',
#   'waterwheels',
#   'wearers',
#   'whirlpool',
#   'wrongdoing',
#   'wedded',
#   'wholesale',
#   'wedding',
#   'wristwatch',
#   'weds',
#   'wagerer',
#   'wiseguys',
#   'whirl',
#   'woodworking',
#   'welled',
#   'whittled',
#   'whirlwind',
#   'wring',
#   'weavings',
#   'window',
#   'wielder',
#   'weightier',
#   'weirs',
#   'widened',
#   'workshops',
#   'weakminded',
#   'woodcutter',
#   'widget',
#   'wishing',
#   'whole',
#   'walkout',
#   'wetness',
#   'writhes',
#   'wives',
#   'witchdoctor',
#   'workpiece',
#   'walkover',
#   'winkle',
#   'warlord',
#   'wrestlers',
#   'warehouses',
#   'walls',
#   'whiffs',
#   'whinnying',
#   'wildoats',
#   'weighty',
#   'writings',
#   'worsen',
#   'woodenness',
#   'witting',
#   'waggons',
#   'waddling',
#   'wrongly',
#   'wizardry',
#   'workability',
#   'welltried',
#   'woebegone',
#   'warehousemen',
#   'wired',
#   'willows',
#   'weathermen',
#   'wields',
#   'woof',
#   'wilier',
#   'weaknesses',
#   'widgeon',
#   'waking',
#   'wicks',
#   'wapitis',
#   'whisperings',
#   'wolfish',
#   'wintering',
#   'womenfolk',
#   'wins',
#   'winch',
#   'wrestler',
#   'wordless',
#   'welcome',
#   'wills',
#   'whipcord',
#   'windy',
#   'washings',
#   'wakefulness',
#   'wicketkeepers',
#   'wellequipped',
#   'webfoot',
#   'waists',
#   'windscreens',
#   'workload',
#   'welding',
#   'whoever',
#   'wordage',
#   'wideranging',
#   'whenever',
#   'witchdoctors',
#   'wrenched',
#   'whisky',
#   'warship',
#   'worsens',
#   'widest',
#   'wildfires',
#   'waterwheel',
#   'waggling',
#   'workers',
#   'wicker',
#   'waistcoats',
#   'wore',
#   'wellknown',
#   'whisking',
#   'wends',
#   'warheads',
#   'woodcocks',
#   'whip',
#   'waged',
#   'wholehearted',
#   'whines',
#   'wavelet',
#   'wadings',
#   'worrisome',
#   'waiving',
#   'washout',
#   'warehouseman',
#   'wilder',
#   'wheelchair',
#   'wheresoever',
#   'winning',
#   'walrus',
#   'wellused',
#   'wheelwrights',
#   'went',
#   'wended',
#   'waive',
#   'willingly',
#   'weekday',
#   'wether',
#   'weighs',
#   'wanly',
#   'wavelike',
#   'wrestle',
#   'whiter',
#   'wordgame',
#   'warbled',
#   'wards',
#   'whacker',
#   'winched',
#   'whelks',
#   'wider',
#   'wean',
#   'wrongful',
#   'waterbed',
#   'warningly',
#   'watercolours',
#   'waxpaper',
#   'wellmeant',
#   'whodunit',
#   'weatherproof',
#   'waders',
#   'westbound',
#   'weevil',
#   'whales',
#   'wobbles',
#   'wimpy',
#   'waxy',
#   'worktop',
#   'wryly',
#   'worshipful',
#   'wizards',
#   'wetland',
#   'waterhole',
#   'wretchedness',
#   ...],
#  'x': ['xraying',
#   'xhosas',
#   'xrays',
#   'xhosa',
#   'xylophonist',
#   'xenon',
#   'xylophone',
#   'xmas',
#   'xenophobe',
#   'xenophobic',
#   'xray',
#   'xenophobia',
#   'xrayed',
#   'xerography'],
#  'y': ['yawl',
#   'yea',
#   'yuppie',
#   'yawns',
#   'yawned',
#   'yardage',
#   'yoke',
#   'yearlings',
#   'yodel',
#   'yore',
#   'yeti',
#   'yelp',
#   'york',
#   'yaks',
#   'yeomen',
#   'yes',
#   'yachting',
#   'yanks',
#   'yachtsmen',
#   'yelps',
#   'youths',
#   'yielding',
#   'you',
#   'yummiest',
#   'yellowy',
#   'yells',
#   'yard',
#   'young',
#   'yawls',
#   'yodeller',
#   'yearns',
#   'yelpings',
#   'yellower',
#   'yawningly',
#   'yuck',
#   'yield',
#   'youth',
#   'yank',
#   'yams',
#   'yippee',
#   'yelping',
#   'yearbook',
#   'yawning',
#   'yummy',
#   'yolks',
#   'yuppies',
#   'yew',
#   'yarn',
#   'yep',
#   'yesterdays',
#   'yardsticks',
#   'yours',
#   'yokel',
#   'yawed',
#   'yell',
#   'yellowed',
#   'yoga',
#   'youngish',
#   'yeast',
#   'yaws',
#   'yam',
#   'yeasty',
#   'yemen',
#   'yelling',
#   'years',
#   'ye',
#   'yukon',
#   'yip',
#   'yeah',
#   'yachtsman',
#   'yawn',
#   'yon',
#   'yuletide',
#   'yearn',
#   'yesteryear',
#   'yorkers',
#   'yale',
#   'yacht',
#   'yankees',
#   'yodelled',
#   'yttrium',
#   'yellings',
#   'yarns',
#   'youngster',
#   'yardstick',
#   'your',
#   'yaps',
#   'yens',
#   'yetis',
#   'year',
#   'yearnings',
#   'yrs',
#   'yearning',
#   'yellowish',
#   'yearling',
#   'yiddish',
#   'yaw',
#   'yap',
#   'youngest',
#   'yogi',
#   'yonder',
#   'yolk',
#   'yelled',
#   'yeas',
#   'youthful',
#   'yellow',
#   'yet',
#   'yoked',
#   'yokes',
#   'yak',
#   'yearly',
#   'yodelling',
#   'yourself',
#   'yowl',
#   'youngsters',
#   'yews',
#   'yokels',
#   'yapping',
#   'yule',
#   'yoyo',
#   'yielded',
#   'yearlong',
#   'yields',
#   'yorker',
#   'yellowing',
#   'yellows',
#   'yeaned',
#   'yachts',
#   'yards',
#   'younger',
#   'yourselves',
#   'yeoman',
#   'yodels',
#   'yen',
#   'yalelock',
#   'yeasts',
#   'yeomanry',
#   'yearned',
#   'yelped',
#   'yearningly',
#   'yearbooks',
#   'yankee',
#   'youthfulness',
#   'yesterday'],
#  'z': ['zambian',
#   'zip',
#   'zephyrs',
#   'zapping',
#   'zeal',
#   'zone',
#   'zoning',
#   'zippy',
#   'zanzibar',
#   'zaniest',
#   'zoologist',
#   'zealots',
#   'zaps',
#   'zag',
#   'zoological',
#   'zeolite',
#   'zulu',
#   'zebras',
#   'zig',
#   'zippers',
#   'zap',
#   'zigzagged',
#   'zoned',
#   'zigzag',
#   'zimbabwe',
#   'zeals',
#   'zoo',
#   'zest',
#   'zebu',
#   'zillions',
#   'zithers',
#   'zeta',
#   'zombies',
#   'zoomed',
#   'zebus',
#   'zulus',
#   'zigzagging',
#   'zeroing',
#   'zinc',
#   'zonal',
#   'zionists',
#   'zionism',
#   'zealot',
#   'zookeepers',
#   'zeus',
#   'zipper',
#   'zephyr',
#   'zipping',
#   'zealously',
#   'zealotry',
#   'zoologists',
#   'zaire',
#   'zillion',
#   'zebra',
#   'zambia',
#   'zealous',
#   'zeppelin',
#   'zambians',
#   'zither',
#   'zooming',
#   'zoom',
#   'zees',
#   'zones',
#   'zooplankton',
#   'zion',
#   'zonation',
#   'zero',
#   'zambezi',
#   'zany',
#   'zionist',
#   'zoos',
#   'zealousness',
#   'zigzags',
#   'zeolites',
#   'zombi',
#   'zestfully',
#   'zeniths',
#   'zesty',
#   'zooms',
#   'zipped',
#   'zappy',
#   'zombie',
#   'zenith',
#   'zoology',
#   'zips',
#   'zeroed']}

# %% [markdown]
# Use your dictionary to create a new dictionary that has each letter of the alphabet and the number of words that start with that letter.

# %%
# print(len(pollywog["a"]))

# print(len(pollywog["b"]))
# print(len(pollywog["c"]))
# print(len(pollywog["d"]))
# print(len(pollywog["q"]))

frog ={
}
for x in pollywog:
    frog[x] = len(pollywog[x])
    
#     [x+ " " + str(len(pollywog[x])) for x in pollywog]
    
for x in (frog):
    print(x + ": " + str(frog[x]))
# Out:
# a: 3479
# b: 3210
# c: 5494
# d: 3776
# e: 2588
# f: 2557
# g: 1836
# h: 2026
# i: 2673
# j: 473
# k: 354
# l: 1837
# m: 2944
# n: 919
# o: 1388
# p: 4563
# q: 290
# r: 3634
# s: 6670
# t: 2881
# u: 1921
# v: 811
# w: 1542
# x: 14
# y: 144
# z: 86

# %% [markdown]
# What is the most common first letter in your list of words? (You can just look at your dictionary to answer this.)
#
# ## Collection Counters 🌶️🌶️🌶️ (aka Ridiculous)
#
# See: https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
#
# What if you'd like to know the most common first letter of words in our list? You could try to somehow sort the dictionary from above.
#
# Or...

# %%
f  = sorted(frog, key=frog.get, reverse = True)

f
# Out:
# ['s',
#  'c',
#  'p',
#  'd',
#  'r',
#  'a',
#  'b',
#  'm',
#  't',
#  'i',
#  'e',
#  'f',
#  'h',
#  'u',
#  'l',
#  'g',
#  'w',
#  'o',
#  'n',
#  'v',
#  'j',
#  'k',
#  'q',
#  'y',
#  'z',
#  'x']

# %%
most_common_first_letter_word_list_variable = f[0]

most_common_first_letter_word_list_variable
# Out:
# 's'

# %% [markdown]
# And of course, I want to know the most common first two letters in my word list, and do it in one line of code!

# %%
# my thought process on how to approach this(I don't know how I would execute it)
# use some sort of one line list comprehension that cycles through the first letter and the second letter then counts them.
# It could maybe store that into a dictionary and make keys for each of the options. 676 keys(not manually done)? 

# I really have no clue how to do this one, I tried

# %% [markdown]
# How many combinations are there?

# %% [markdown]
# ##### There are 676 combinations
